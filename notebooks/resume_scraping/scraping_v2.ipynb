# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
from bs4 import BeautifulSoup
import time, json, re, random, requests
from typing import List, Optional
from pydantic import BaseModel

# %%
def scrape_resume_links(category_url, max_pages=200):
    """Scrape resume links from a given category (multiple pages)."""
    resume_links = []
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                      "AppleWebKit/537.36 (KHTML, like Gecko) "
                      "Chrome/116.0 Safari/537.36"
    }

    session = requests.Session()
    session.headers.update(headers)

    for page in range(1, max_pages + 1):
        url = f"{category_url}/page/{page}"
        print(f"[+] Scraping {url}")

        r = session.get(url)
        if r.status_code != 200:
            print(f"[-] Page {page} returned {r.status_code}, stopping.")
            break

        soup = BeautifulSoup(r.text, "html.parser")
        links = [a['href'] for a in soup.select("table.hit-table h4 a")]

        if not links:  # No more resumes
            print(f"[-] No resumes found on page {page}, stopping.")
            break

        resume_links.extend(links)

        # small random delay (just to avoid hammering)
        time.sleep(random.uniform(0.3, 0.7))

    return resume_links

# %%
categories = [
    "https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes",
    "https://www.hireitpeople.com/resume-database/71-sap-resumes",
    "https://www.hireitpeople.com/resume-database/77-oracle-resumes",
    "https://www.hireitpeople.com/resume-database/78-oracle-dba-resumes",
]

categories = [
    "https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes",
]


num_pages = 500    # each page contains 10 resumes

# %%
all_links = {}

with ThreadPoolExecutor(max_workers=len(categories)) as executor:
    futures = {executor.submit(scrape_resume_links, cat_url, max_pages=500): cat_url for cat_url in categories}
    for future in as_completed(futures):
        cat_url = futures[future]
        try:
            links = future.result()
            all_links[cat_url] = links
            print(f"[✓] Collected {len(links)} resumes from {cat_url}")
        except Exception as e:
            print(f"[!] Failed to scrape {cat_url}: {e}")

# flatten list
all_resume_links = [link for links in all_links.values() for link in links]
# Out:
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/1
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/2
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/3
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/4
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/5
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/6
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/7
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/8
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/9
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/10
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/11
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/12
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/13
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/14
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/15
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/16
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/17
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/18
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/19
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/20
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/21
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/22
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/23
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/24
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/25
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/26
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/27
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/28
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/29
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/30
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/31
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/32
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/33
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/34
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/35
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/36
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/37
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/38
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/39
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/40
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/41
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/42
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/43
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/44
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/45
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/46
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/47
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/48
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/49
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/50
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/51
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/52
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/53
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/54
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/55
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/56
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/57
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/58
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/59
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/60
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/61
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/62
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/63
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/64
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/65
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/66
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/67
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/68
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/69
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/70
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/71
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/72
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/73
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/74
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/75
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/76
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/77
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/78
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/79
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/80
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/81
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/82
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/83
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/84
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/85
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/86
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/87
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/88
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/89
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/90
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/91
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/92
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/93
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/94
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/95
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/96
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/97
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/98
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/99
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/100
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/101
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/102
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/103
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/104
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/105
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/106
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/107
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/108
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/109
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/110
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/111
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/112
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/113
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/114
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/115
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/116
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/117
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/118
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/119
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/120
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/121
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/122
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/123
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/124
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/125
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/126
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/127
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/128
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/129
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/130
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/131
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/132
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/133
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/134
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/135
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/136
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/137
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/138
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/139
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/140
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/141
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/142
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/143
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/144
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/145
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/146
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/147
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/148
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/149
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/150
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/151
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/152
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/153
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/154
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/155
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/156
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/157
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/158
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/159
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/160
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/161
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/162
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/163
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/164
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/165
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/166
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/167
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/168
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/169
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/170
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/171
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/172
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/173
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/174
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/175
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/176
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/177
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/178
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/179
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/180
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/181
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/182
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/183
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/184
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/185
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/186
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/187
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/188
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/189
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/190
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/191
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/192
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/193
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/194
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/195
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/196
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/197
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/198
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/199
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/200
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/201
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/202
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/203
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/204
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/205
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/206
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/207
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/208
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/209
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/210
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/211
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/212
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/213
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/214
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/215
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/216
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/217
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/218
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/219
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/220
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/221
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/222
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/223
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/224
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/225
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/226
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/227
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/228
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/229
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/230
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/231
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/232
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/233
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/234
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/235
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/236
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/237
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/238
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/239
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/240
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/241
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/242
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/243
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/244
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/245
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/246
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/247
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/248
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/249
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/250
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/251
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/252
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/253
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/254
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/255
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/256
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/257
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/258
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/259
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/260
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/261
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/262
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/263
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/264
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/265
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/266
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/267
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/268
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/269
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/270
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/271
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/272
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/273
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/274
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/275
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/276
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/277
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/278
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/279
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/280
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/281
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/282
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/283
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/284
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/285
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/286
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/287
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/288
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/289
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/290
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/291
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/292
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/293
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/294
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/295
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/296
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/297
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/298
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/299
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/300
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/301
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/302
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/303
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/304
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/305
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/306
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/307
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/308
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/309
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/310
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/311
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/312
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/313
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/314
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/315
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/316
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/317
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/318
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/319
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/320
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/321
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/322
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/323
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/324
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/325
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/326
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/327
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/328
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/329
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/330
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/331
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/332
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/333
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/334
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/335
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/336
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/337
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/338
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/339
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/340
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/341
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/342
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/343
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/344
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/345
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/346
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/347
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/348
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/349
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/350
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/351
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/352
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/353
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/354
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/355
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/356
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/357
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/358
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/359
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/360
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/361
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/362
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/363
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/364
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/365
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/366
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/367
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/368
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/369
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/370
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/371
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/372
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/373
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/374
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/375
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/376
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/377
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/378
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/379
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/380
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/381
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/382
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/383
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/384
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/385
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/386
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/387
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/388
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/389
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/390
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/391
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/392
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/393
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/394
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/395
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/396
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/397
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/398
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/399
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/400
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/401
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/402
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/403
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/404
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/405
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/406
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/407
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/408
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/409
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/410
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/411
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/412
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/413
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/414
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/415
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/416
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/417
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/418
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/419
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/420
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/421
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/422
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/423
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/424
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/425
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/426
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/427
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/428
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/429
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/430
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/431
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/432
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/433
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/434
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/435
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/436
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/437
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/438
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/439
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/440
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/441
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/442
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/443
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/444
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/445
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/446
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/447
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/448
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/449
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/450
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/451
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/452
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/453
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/454
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/455
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/456
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/457
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/458
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/459
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/460
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/461
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/462
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/463
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/464
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/465
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/466
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/467
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/468
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/469
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/470
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/471
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/472
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/473
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/474
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/475
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/476
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/477
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/478
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/479
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/480
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/481
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/482
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/483
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/484
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/485
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/486
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/487
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/488
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/489
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/490
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/491
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/492
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/493
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/494
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/495
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/496
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/497
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/498
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/499
# [+] Scraping https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/page/500
# [✓] Collected 5000 resumes from https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes

# %%
all_resume_links
# Out:
# ['https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/628272-teradata-dba-resume-hoffman-estates-il-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/628245-senior-oracle-developer-resume-nj-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/628214-oracle-developer-production-support-resume-st-louis-mo',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/628085-oracle-soa-bpel-consultant-resume-wilmington-delaware-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/628083-oracle-soa-bpel-consultant-resume-wilmington-delaware',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/628034-oracle-soa-consultant-resume-camarillo-ca-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/628032-oracle-soa-consultant-resume-camarillo-ca-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627972-senior-obiee-developer-resume-st-louis-mo-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627841-sr-database-administrator-resume-vernon-ca-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627829-oracle-dba-resume-chicago-il-39',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627804-sr-database-administrator-resume-chesterfield-mo-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627786-oracle-database-administrator-resume-dubuque-ia-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627753-oracle-pl-sql-developer-resume-san-antonio-tx-46',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627752-oracle-pl-sql-developer-resume-san-antonio-tx-45',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627748-oracle-techno-functional-consultant-resume-jacksonville-fl-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627746-oracle-techno-functional-consultant-resume-jacksonville-fl',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627621-oracle-pl-sql-developer-resume-san-antonio-tx-44',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627447-java-oracle-programmer-resume-california',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627392-oracle-dba-resume-ct-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627271-oracle-financials-functional-business-analyst-resume-san-diego-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627268-oracle-dba-resume-greenville-sc-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627191-finance-functional-consultant-resume-fremont-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627167-oracle-developer-resume-nc',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627139-sr-oracle-database-administrator-resume-charlotte-nc-17',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/627123-sr-oracle-pl-sql-developer-resume-northbrook-illinois',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626983-account-tech-subject-matter-expert-tech-lead-resume-7',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626897-lead-atg-developer-technical-lead-resume-minneapolis-mn-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626896-lead-atg-developer-technical-lead-resume-minneapolis-mn',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626800-oracle-consultant-resume-framingham-ma',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626688-oracle-pl-sql-developer-resume-san-antonio-tx-38',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626621-sr-oracle-dba-resume-warren-nj',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626568-oracle-pl-sql-developer-resume-san-antonio-tx-31',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626474-senior-oracle-dba-resume-dallas-tx-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626343-oracle-programmer-resume-9',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626342-oracle-programmer-resume-8',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626341-oracle-programmer-resume-7',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626090-senior-oracle-pl-sql-developer-resume-northbrook-il-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626073-oracle-dba-resume-plano-tx-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626064-oracle-sql-server-developer-resume-memphis-tn',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/626056-junior-oracle-dba-intern-resume-de',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/625994-sr-oracle-dba-application-dba-resume-upper-saddle-river-nj',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/625826-senior-oracle-developer-resume-stamford-ct',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/625731-oracle-database-administrator-l3-resume-il',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/625709-oracle-database-administrator-resume-829',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/625485-oracle-apps-dba-resume-pleasanton-ca-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/625474-oracle-applications-functional-consultant-resume-moosic-pa-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/625472-oracle-applications-functional-consultant-resume-moosic-pa-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/625441-applications-dba-resume-miami-fl',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/625433-oracle-vcp-production-support-resume-sidney-oh-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/625431-oracle-vcp-production-support-resume-sidney-oh',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/625195-sr-hyperion-essbase-planning-hfm-consultant-resume-chicago-il',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624786-oracle-biee-developer-resume-oshkosh-wi-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624711-oracle-developer-dba-resume-dallas-tx',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624652-oracle-dba-resume-new-york-14',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624561-plsql-lead-developer-resume-san-antonio-tx-17',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624517-oracle-dba-resume-md-7',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624508-oracle-financial-functional-consultant-resume-chicago-il',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624478-oracle-pl-sql-developer-resume-san-antonio-tx-10',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624476-oracle-pl-sql-developer-resume-san-antonio-tx-8',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624475-oracle-financial-consultant-resume-new-jersey-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624473-oracle-financial-consultant-resume-new-jersey',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624448-financials-functional-consultant-resume-los-angeles',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624414-techno-functional-consultant-analyst-resume-research-triangle-park-nc-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624412-techno-functional-consultant-analyst-resume-research-triangle-park-nc',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624382-oracle-developer-oracle-dba-resume-des-moines-ia',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624368-oracle-financial-functional-consultant-resume-washington-d-c',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624330-oracle-apps-techno-functional-consultant-resume-north-wales-pa-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624328-technical-consultant-resume-pa',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624268-oracle-techno-functional-analyst-resume-chicago-il',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624154-oracle-apps-technical-analyst-resume-warren-nj',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624038-oracle-dba-resume-ny-7',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/624023-senior-consultant-oracle-apps-techno-functional-upgrade-consultant-resume-sanjose-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623926-p2p-functional-analyst-resume-san-diego-ca-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623924-p2p-functional-analyst-resume-san-diego-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623869-oracle-applications-techno-functional-consultant-resume-ca-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623867-oracle-applications-techno-functional-consultant-resume-ca-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623844-senior-hyperion-developer-consultant-resume-naperville-il',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623838-solution-architect-resume-houston-tx-7',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623836-hfm-fdm-administration-and-support-resume-san-jose-ca-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623834-hyperion-administrator-developer-resume-el-segundo-ca-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623832-hyperion-administrator-developer-resume-el-segundo-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623830-sr-hyperion-consultant-resume-pa',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623829-hyperion-admin-developer-resume-chicago-il-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623826-hyperion-developer-resume-brooklyn-park-mn-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623824-hyperion-developer-resume-brooklyn-park-mn',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623821-hyperion-essbase-and-planning-developer-resume-denver-co',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623819-senior-business-analyst-hyperion-resume-livingston-nj-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623768-oracle-apps-functional-consultant-resume-la-ca-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623767-oracle-apps-functional-consultant-resume-la-ca-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623718-oracle-finance-functional-consultant-resume-brooklyn-ny',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623685-oracle-apps-techno-functional-consultant-resume-west-des-moines-ia-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623684-oracle-apps-techno-functional-consultant-resume-west-des-moines-ia-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623661-oracle-dba-resume-pittsburg-pa-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623658-oracle-dba-resume-pittsburg-pa-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623648-oracle-technical-consultant-resume-horsham-pa-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623646-oracle-technical-consultant-resume-horsham-pa',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623595-sr-oracle-pl-sql-developer-resume-tampa-fl-12',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623576-obiee-lead-resume-phoenix-az-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623574-obiee-lead-resume-phoenix-az-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623532-sr-oracle-applications-dba-resume-oak-brook-il-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623419-application-programmer-it-analyst-resume-research-triangle-park-nc-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623417-application-programmer-it-analyst-resume-research-triangle-park-nc',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623293-oracle-apps-dba-resume-memphis-tn',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623285-sr-oracle-dba-resume-san-francisco-ca-8',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623275-sr-hyperion-planning-and-hfm-consultant-resume-washington-dc',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623132-senior-oracle-dba-resume-atlanta-ga-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623131-senior-oracle-dba-resume-atlanta-ga-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623130-senior-oracle-dba-resume-atlanta-ga-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623126-sr-oracle-developer-resume-sacramento-ca-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623124-sr-oracle-developer-resume-sacramento-ca-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623063-oracle-dba-resume-des-plaines-il-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623042-hyperion-essbase-developer-resume-austin-tx-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/623014-oracle-dba-resume-detroit-mi-11',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/622796-sr-oracle-pl-sql-developer-resume-tampa-fl-11',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/622604-oracle-developer-resume-cookeville-tn',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/622563-sr-oracle-developer-resume-charlotte-nc-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/622401-oracle-apps-techno-functional-consultant-resume-webster-ny-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/622277-soa-consultant-resume-windsor-ct-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/622275-soa-consultant-resume-windsor-ct-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/622161-oracle-developer-resume-foster-city-ca-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/622160-oracle-developer-resume-foster-city-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/622154-sr-oracle-developer-and-i-t-administrator-resume-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/622116-lead-database-administrator-resume-nj',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/622114-lead-database-administrator-resume-nj',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/622058-etl-oracle-developer-resume-sfo-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/621979-oracle-database-administrator-resume-oh-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/621888-oracle-soa-bpm-developer-resume-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/621877-cognos-developer-resume-new-york',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/621839-oracle-dba-resume-washington-dc-17',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/621483-technical-architect-senior-soa-developer-resume-belmont-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/621482-oracle-apps-developer-resume-pittsburgh-pa',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/621370-oracle-cdc-developer-resume-md-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/621368-oracle-developer-resume-md-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/621158-sr-oracle-database-admin-resume-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/620595-sr-oracle-database-administrator-resume-east-windsor-nj-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/620325-sr-database-administrator-resume-bloomington-il-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/620235-oracle-applications-technical-developer-resume-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/620233-oracle-applications-technical-developer-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/620077-sr-oracle-database-administrator-resume-minneapolis-mn-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/620033-oracle-dba-resume-il-26',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/620031-senior-oracle-dba-resume-deerfield-il-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619983-sr-oracle-database-administrator-resume-east-windsor-nj',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619981-sr-oracle-database-administrator-resume-holland-mi-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619980-oracle-dba-resume-honolulu-hi',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619977-sr-oracle-database-administrator-resume-holland-mi',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619975-oracle-dba-developer-resume-hi',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619974-sr-obiee-developer-obiee-11g-resume-providence-ri',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619845-hyperion-planning-and-essbase-application-tower-lead-resume-cincinnati-oh-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619745-oracle-functional-consultant-resume-dallas-tx-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619744-oracle-functional-consultant-resume-dallas-tx-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619743-oracle-functional-consultant-resume-dallas-tx-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619702-release-and-infrastructure-management-resume-hoboken-nj-18',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619701-release-and-infrastructure-management-resume-hoboken-nj-17',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619700-release-and-infrastructure-management-resume-hoboken-nj-16',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619668-production-support-resume-jersey-city-nj-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619640-release-and-infrastructure-management-resume-jersey-city-nj-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619639-release-and-infrastructure-management-resume-jersey-city-nj-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619637-senior-obiee-consultant-resume-milpitas-ca-11',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619635-senior-obiee-consultant-resume-milpitas-ca-9',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619515-oracle-and-informatica-developer-resume-al',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619486-sr-oracle-developer-resume-rockville-md-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619446-senior-oracle-functional-consultant-resume-hoboken-nj-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619444-senior-oracle-functional-consultant-resume-hoboken-nj',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619409-oracle-techno-functional-consultant-resume-sanjose-ca-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619407-oracle-techno-functional-consultant-resume-sanjose-ca-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619385-senior-oracle-functional-consultant-resume-east-greenville-pa-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619384-senior-oracle-functional-consultant-resume-east-greenville-pa-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619306-oracle-techno-functional-consultant-resume-sanjose-ca-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619304-oracle-techno-functional-consultant-resume-sanjose-ca-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619282-oracle-technical-consultant-resume-sanjose-ca-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619281-oracle-technical-consultant-resume-sanjose-ca-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619261-database-engineer-resume-austin-tx',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619244-techno-functional-scm-consultant-resume-houston-12',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619243-techno-functional-scm-consultant-resume-houston-11',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619239-oracle-functional-consultant-resume-pittsburgh-pa-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619238-oracle-functional-consultant-resume-pittsburgh-pa-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619167-oracle-techno-functional-consultant-resume-sanjose-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619165-oracle-techno-functional-consultant-resume-sanjose-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/619163-oracle-techno-functional-consultant-resume-sanjose-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/618888-sr-oracle-developer-resume-morton-grove-il-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/618887-sr-oracle-developer-resume-morton-grove-il-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/618571-sr-obiee-developer-resume-sacramento-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/618367-obiee-developer-resume-bentonville-ar-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/617803-release-and-infrastructure-management-resume-jersey-city-nj-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/617802-release-and-infrastructure-management-resume-jersey-city-nj-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/617773-application-support-resume-hoboken-nj',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/617769-senior-developer-consultant-resume-12',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/617768-senior-developer-consultant-resume-11',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/617512-release-and-environment-management-resume-mooresville-nc-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/617510-release-and-environment-management-resume-mooresville-nc',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/617509-release-and-infrastructure-management-resume-hoboken-nj-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/617508-release-and-infrastructure-management-resume-hoboken-nj-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/617492-sr-oracle-database-administrator-resume-norfolk-virginia-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/616427-software-engineer-resume-4053',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/616254-oracle-fusion-middleware-consultant-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/616056-functional-lead-resume-ca-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/616047-avp-senior-programmer-analyst-resume-vienna-virginia',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/616016-functional-business-analyst-resume-chicago-il-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615993-application-developer-resume-montgomery-al',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615988-supply-chain-management-scm-services-transformation-functional-architect-resume-schaumburg-il',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615912-srm-functional-consultant-resume-chesterbrook-pa-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615881-functional-lead-sme-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615786-business-functional-analyst-resume-virginia-beach-va-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615646-oracle-developer-resume-520',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615641-siebel-systems-analyst-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615623-consultant-resume-schaumburg-il-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615576-lead-prog-analyst-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615532-oracle-applications-technical-consultant-resume-schaumburg-il',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615344-oracle-applications-dba-resume-cranston-ri',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615268-soa-consultant-oracle-fusion-developer-resume-harrisburg-pa',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615225-osb-oracle-fusion-developer-resume-los-angeles-ca-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615223-osb-oracle-fusion-developer-resume-los-angeles-ca-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615065-consultant-resume-schaumburg-il-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/615018-software-developer-resume-2935',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614900-oracle-apps-dba-resume-105',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614764-hyperion-developer-administrator-resume-livingston-nj-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614728-sr-oracle-database-administrator-resume-rtp-nc-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614727-sr-oracle-database-administrator-resume-rtp-nc-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614719-oracle-financials-lead-resume-santa-clarita-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614717-oracle-financials-business-analyst-resume-santa-clarita-ca-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614674-sr-oracle-database-administrator-resume-wilmington-de',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614533-oracle-developer-resume-carrollton-tx',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614467-sr-techno-functional-specialist-resume-atlanta-ga-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614225-sr-oracle-dba-resume-columbus-ohio-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614222-sr-oracle-dba-resume-columbus-ohio',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614212-oracle-apps-techno-functional-consultant-resume-lehi-ut',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614191-oracle-finance-functional-lead-consultant-resume-albany-ny-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/614189-oracle-finance-functional-lead-consultant-resume-albany-ny',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613779-oracle-database-administrator-resume-dallas-tx-22',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613769-sr-workday-consultant-resume-ny-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613767-sr-workday-consultant-resume-ny',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613642-techno-functional-consultant-resume-chicago-il-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613587-technical-consultant-resume-482',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613581-technical-consultant-resume-houston-tx-7',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613566-scm-track-lead-resume-irving-tx',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613522-oracle-linux-virtualization-consultant-resume-frisco-tx',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613456-sr-oracle-developer-resume-ny-ny',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613421-oracle-e-business-suite-ba-functional-consultant-resume-ny-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613417-functional-consultant-oracle-ebs-r12-resume-silver-spring-md-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613415-senior-oracle-programmer-analyst-resume-austin-texas',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613414-senior-oracle-consultant-project-manager-resume-houston-tx',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613399-oracle-e-business-suite-ba-functional-consultant-resume-ny',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613352-hyperion-consultant-resume-bellevue-wa-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613322-sr-oracle-developer-resume-nc-10',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613321-sr-oracle-developer-resume-nc-9',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613307-sr-oracle-dba-resume-nc-9',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613231-sr-oracle-soa-bpel-osb-b2b-developer-resume-shelton-ct-7',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613230-sr-oracle-soa-bpel-osb-b2b-developer-resume-shelton-ct-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613227-application-developer-resume-nj-14',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613225-application-developer-resume-nj-12',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613162-solutions-architect-resume-380',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613103-oracle-database-administrator-resume-washington-dc-9',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613073-oracle-techno-functional-consultant-resume-sidney-oh-11',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613028-system-analyst-techno-functional-resume-florida',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/613001-global-supply-chain-lead-resume-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612991-senior-consultant-resume-houston-tx-15',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612985-team-lead-resume-albany-ny',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612903-oracle-ebs-technical-lead-resume-maumee-oh-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612902-oracle-ebs-technical-lead-resume-maumee-oh',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612898-oracle-database-administrator-resume-moorestown-nj-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612864-oracle-dba-database-analyst-resume-san-francisco-california-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612862-oracle-dba-database-analyst-resume-san-francisco-california-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612854-oracle-database-administrator-resume-nj-8',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612799-functional-consultant-oracle-r12-1-resume-tx-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612781-senior-enterprise-data-architect-resume-atlanta-ga-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612778-sr-techno-functional-consultant-resume-keene-nh-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612677-obiee-administrator-resume-ks-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612672-oracle-pl-sql-developer-resume-flint-mi',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612604-oracle-database-administrator-resume-indianapolis-in-7',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612591-oracle-consultant-and-data-lead-resume-california',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612578-odi-and-obiee-developer-resume-chicago-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612565-oralce-pl-sql-developer-resume-va',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612504-oracle-soa-osb-developer-resume-ada-mi-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612444-oracle-applications-techno-functional-consultant-resume-houston-tx',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612405-oracle-ebs-senior-techno-functional-consultant-resume-cincinnati-oh-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612403-oracle-ebs-senior-techno-functional-consultant-resume-cincinnati-oh-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612360-sr-techno-functional-specialist-resume-atlanta-ga',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612304-consultant-resume-san-diego-12',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612273-scm-functional-consultant-resume-shumburg-il',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612208-oracle-soa-weblogic-administrator-resume-seattle-wa-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612205-oracle-fusion-middleware-soa-administrator-resume-new-york-ny-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612193-sr-oracle-developer-resume-detroit-mi-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612185-oracle-developer-resume-detroit-mi-9',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/612184-oracle-developer-resume-jersey-city-nj-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/611868-oracle-bpm-developer-resume-mt-laurel-nj',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/611865-lead-oracle-apps-database-consultant-resume-o-fallon-mo-11',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/611840-microsoft-dynamics-ax-consultant-resume-tx-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/611827-sr-oracle-apps-dba-resume-salem-or',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/611811-techno-functional-consultant-resume-ma',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/611734-oracle-adf-consultant-resume-nc',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/611661-oracle-11i-techincal-functional-oracle-apps-rice-developer-resume-quantico-va',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/611647-functional-consultant-oracle-ebs-r12-resume-silver-spring-md-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/611614-sr-oracle-apps-dba-resume-san-francisco-ca-15',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/611586-sr-oracle-dba-resume-louisville-ky-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610850-obiee-administrator-resume-ks-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610848-obiee-administrator-resume-ks-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610819-oracle-database-administrator-resume-south-san-francisco-ca-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610667-sr-oracle-pl-sql-unix-shell-scripting-developer-resume-ny-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610666-sr-oracle-pl-sql-unix-shell-scripting-developer-resume-ny-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610660-oracle-dba-resume-knoxville-tn-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610616-sr-hyperion-essbase-planning-report-consultant-resume-tulsa-ok-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610615-sr-hyperion-essbase-planning-report-consultant-resume-tulsa-ok-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610587-techno-functional-consultant-oracle-oaf-developer-resume-mahwah-nj-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610585-techno-functional-consultant-oracle-oaf-developer-resume-mahwah-nj-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610457-oracle-order-to-cash-functional-consultant-resume-denver-co-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610456-oracle-order-to-cash-functional-consultant-resume-denver-co-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610052-sr-oracle-administrator-resume-ny',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/610017-oracle-pl-sql-developer-resume-los-angeles-ca-10',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609882-oracle-dba-resume-oklahoma-city-oklahoma-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609868-sr-oracle-apps-dba-resume-san-francisco-ca-12',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609849-senior-developer-resume-new-york-59',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609787-sr-oracle-dba-resume-louisville-ky-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609767-sr-middleware-oracle-weblogic-jboss-administrator-resume-houston-tx-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609766-sr-middleware-oracle-weblogic-jboss-administrator-resume-houston-tx-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609474-functional-financial-consultant-resume-pittsburgh-pa-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609377-sr-hyperion-drm-essbase-planning-consultant-resume-pittsburgh-pa-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609375-oracle-techno-functional-consultant-resume-sidney-oh-7',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609374-oracle-techno-functional-consultant-resume-sidney-oh-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609307-sr-obiee-consultant-resume-new-york-ny-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609280-techno-functional-scm-consultant-resume-houston-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609278-techno-functional-scm-consultant-resume-houston-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609158-lead-oracle-developer-resume-chicago-il-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609091-oracle-dba-resume-annapolis-md',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609013-oracle-database-administrator-resume-alexandria-va-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/609004-sr-oracle-soa-bpel-osb-b2b-developer-resume-shelton-ct-8',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608984-senior-obiee-bi-apps-consultant-resume-pheonix-az-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608889-senior-obiee-consultant-resume-liver-more-ca-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608887-senior-obiee-consultant-resume-liver-more-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608851-senior-obiee-consultant-resume-milpitas-ca-8',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608849-senior-obiee-consultant-resume-milpitas-ca-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608848-project-lead-and-sr-functional-consultant-scm-resume-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608846-project-lead-and-sr-functional-consultant-scm-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608805-finance-techno-functional-consultant-resume-palo-alto-ca-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608803-finance-techno-functional-consultant-resume-palo-alto-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608766-techno-functional-consultant-resume-palo-alto-ca-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608764-techno-functional-consultant-resume-palo-alto-ca-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608760-oracle-ebs-consultant-resume-memphis-tn-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608758-oracle-ebs-consultant-resume-memphis-tn-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608735-techno-functional-consultant-resume-mountainview-ca-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608733-techno-functional-consultant-resume-mountainview-ca-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608672-lead-oracle-apps-database-consultant-resume-orlando-fl-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608670-lead-oracle-apps-database-consultant-resume-orlando-fl',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608608-financial-functional-consultant-resume-foster-city-ca-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608606-financial-functional-consultant-resume-foster-city-ca-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608587-lead-oracle-apps-database-consultant-resume-o-fallon-mo-8',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608547-oracle-dba-resume-1328',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608490-sr-oracle-dba-resume-rahway-new-jersey-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608427-odi-technical-consultant-resume-stony-brook-ny-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608426-odi-technical-consultant-resume-stony-brook-ny-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608394-sr-obiee-developer-resume-kansas-city-mo-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608365-siebel-analytics-oracle-bi-obiee-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608291-oracle-soa-developer-resume-beaverton-or-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608254-oracle-pl-sql-developer-resume-ny-12',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608241-sr-oracle-developer-resume-new-jersey-nj-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608094-sr-oracle-developer-resume-nc-7',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608033-principal-consultant-resume-maryland',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/608025-oracle-fusion-middleware-admin-resume-irving-t-x',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/607975-oracle-consultant-resume-cary-north-carolina',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/607963-oracle-bpel-process-manager-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/607960-functional-consultancy-business-analyst-techno-functional-consultant-resume-tx',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/607939-senior-oracle-developer-resume-nj',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/607932-functional-consultant-oracle-ebs-r12-resume-silver-spring-md',
# ...
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/583614-sr-soa-administrator-resume-charlotte-nc-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/583613-sr-soa-administrator-resume-charlotte-nc-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/583611-sr-soa-administrator-resume-charlotte-nc',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/583422-database-administrator-engineering-l2-l3-support-resume-peapack-gladstone-nj-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/583362-pl-sql-resume-new-york-ny-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582836-agile-plm-functional-technical-consultant-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582789-senior-oracle-database-administrator-resume-oaks-pennsylvania-14',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582787-senior-oracle-database-administrator-resume-oaks-pennsylvania-12',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582783-techno-functional-lead-consultant-resume-7',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582782-techno-functional-lead-consultant-resume-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582768-oracle-application-database-administrator-resume-san-diego-california-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582750-oracle-applications-techno-functional-consultant-resume-california-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582749-oracle-applications-techno-functional-consultant-resume-california',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582729-obiee-consultant-resume-indianapolis-in-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582643-senior-oracle-database-administrator-resume-oaks-pennsylvania-11',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582641-senior-oracle-database-administrator-resume-oaks-pennsylvania-9',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582605-senior-oracle-database-administrator-resume-san-francisco-california-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582389-senior-oracle-database-administrator-resume-tx-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582287-mfg-scm-lead-solution-architect-and-business-process-management-resume-louisville-ky-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/582202-oracle-developer-resume-virginia-beach-va-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/581936-sr-data-engineer-resume-seattle-wa-11',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/581846-oracle-dba-resume-1261',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/581683-senior-oracle-database-administrator-resume-oaks-pennsylvania-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/581563-oracle-hcm-cloud-consultant-resume-26',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/581533-oracle-database-administrator-resume-761',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/581489-oracle-financials-functional-resume-san-jose-ca-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/581487-oracle-financials-functional-resume-san-jose-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/581361-oracle-ebs-techno-functional-developer-lead-oracle-r12-erp-resume-houston-tx',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/581311-oracle-ebs-functional-p2p-consultant-resume-ashburn-va',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/581142-obiee-odi-developer-resume-atlanta-ga',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/581141-senior-obiee-admin-developer-resume-irving-tx',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/581022-oracle-ebs-developer-resume-36',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580911-software-engineer-oracle-developer-resume-detroit-mi',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580887-techno-functional-consultant-solution-architect-resume-charlotte',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580863-sr-oracle-database-administrator-resume-atlanta-ga-7',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580799-obiee-architect-resume-irvine-california-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580604-financials-functional-consultant-resume-ann-arbor-mi',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580603-oracle-financials-functional-analyst-resume-st-louis-mo',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580473-tech-lead-senior-developer-resume-14',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580472-tech-lead-senior-developer-resume-13',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580382-senior-database-administrator-resume-oaks-pennsylvania',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580318-oracle-financial-functional-analyst-resume-ut',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580308-oracle-ebs-financial-techno-functional-consultant-resume-nc',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580256-oracle-xml-gate-architect-resume-lincolnshire-il-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580255-oracle-xml-gate-architect-resume-lincolnshire-il',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580091-oracle-developer-report-writer-resume-plano-tx-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580090-oracle-developer-report-writer-resume-plano-tx',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580057-oracle-soa-lead-resume-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580054-sr-oracle-biapps7-9-63-obiee-11g-informatica9-0-etl-dac-architect-developer-resume-texas-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580053-sr-oracle-biapps7-9-63-obiee-11g-informatica9-0-etl-dac-architect-developer-resume-texas-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580052-sr-oracle-biapps7-9-63-obiee-11g-informatica9-0-etl-dac-architect-developer-resume-texas',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/580006-sr-oracle-database-administrator-resume-miami-fl-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/579937-sr-oracle-pl-sql-developer-resume-chicago-il-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/579656-soa-developer-resume-washington-dc-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/579598-oracle-projects-functional-consultant-resume-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/579597-oracle-projects-functional-consultant-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/579493-oracle-dba-resume-tx-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/579265-oracle-pl-sql-lead-resume-owings-mills-md-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578819-oracle-ebs-functional-analyst-resume-norfolk-va',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578810-team-lead-project-manager-resume-tx-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578754-oracle-pl-sql-developer-resume-des-moines-iowa-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578660-oracle-financial-functional-consultant-resume-seal-beach-ca',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578536-oracle-dba-resume-il-20',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578468-solution-architect-resume-664',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578466-functional-consultant-resume-167',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578366-sr-weblogic-administrator-middleware-administrator-resume-lexington-ky-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578340-sr-oracle-developer-resume-tulsa-ok-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578339-sr-oracle-developer-resume-tulsa-ok-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578177-senior-oracle-ebs-project-manager-resume-chicago-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578175-senior-oracle-ebs-project-manager-resume-chicago',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578156-sr-oracle-business-analyst-resume-austin-tx-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578007-oracle-developer-resume-freeport-ny-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/578006-oracle-developer-resume-freeport-ny-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/577951-db2-udb-dba-resume-il-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/577845-oracle-adf-developer-resume-torrance-ca-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/577736-sr-oracle-apps-dba-consultant-resume-red-wood-city-ca-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/577611-oracle-apps-technical-lead-resume-houston-tx-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/577609-oracle-soa-bpel-sql-developer-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/577607-oracleebstechnofunctionalconsultant-resume-webster-ny',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/577512-senior-oracle-ebs-technical-consultant-resume-waukegan-il',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/577322-sr-oracle-database-administrator-resume-atlanta-ga-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/577315-hcm-lead-consultant-resume-pittsburgh-pa-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/577313-hcm-lead-consultant-resume-pittsburgh-pa',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/577229-oracle-dba-resume-huntsville-tx-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/577200-oracle-dba-resume-groton-ct-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576931-oracle-technical-consultant-resume-reston-va-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576929-oracle-technical-consultant-resume-reston-va',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576838-oracle-erp-functional-tester-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576833-sr-oracle-soa-developer-resume-19',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576828-sr-oracle-developer-resume-260',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576801-functional-analyst-supply-chain-resume-schaumburg-il-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576799-functional-analyst-supply-chain-resume-schaumburg-il',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576798-oracle-lead-financials-functional-analyst-resume-portland-or-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576797-oracle-lead-financials-functional-analyst-resume-portland-or-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576774-principal-technical-analyst-resume-columbus-oh-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576745-oracle-database-administrator-resume-richmond-va-10',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576714-oracle-soa-resume-allentown-pa-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576713-oracle-soa-resume-allentown-pa-4',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576686-oracle-apps-dba-consultant-resume-15',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576636-sr-oracle-e-business-consultant-resume-scottsdale-az-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576568-bi-business-analyst-obiee-developer-resume-oakbrook-il-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576425-big-data-engineer-spark-developer-resume-indianapolis-in',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576394-sr-oracle-e-business-consultant-resume-scottsdale-az',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576293-senior-obiee-architect-pm-resume-raleigh-nc',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576272-senior-oracle-ebs-analyst-resume-orlando-fl',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576221-oracle-financials-fah-functional-lead-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576211-sr-oracle-application-developer-resume-tx-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576209-sr-oracle-application-developer-resume-tx',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576057-oracle-dba-resume-dallas-tx-21',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/576000-oracle-soa-resume-allentown-pa-2',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/575867-sr-oracle-developer-resume-addison-tx-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/575865-sr-oracle-developer-resume-addison-tx-1',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/575828-sr-consultant-resume-ny-6',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/575803-oracle-ebs-production-support-lead-resume-marlborough-ma-5',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/575802-oracle-ebs-production-support-lead-resume-marlborough-ma-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/575743-oracle-developer-resume-461',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/575742-oracle-ebs-advanced-benefits-module-sme-resume',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/575735-senior-oracle-apps-dba-resume-indianapolis-in',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/575734-oracle-developer-resume-houston-tx-3',
#  'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/575630-oracle-dba-resume-chicago-il-35',
#  ...]

# %%
import requests
from bs4 import BeautifulSoup, NavigableString, Tag

def fetch_and_print_dom(url, max_depth=3):
    
    """
    Fetches HTML content from a URL and prints a tree representation of the DOM.

    Args:
        url (str): The URL to fetch.
        max_depth (int): Maximum depth of the tree to print.
    """
    # Step 1: Fetch HTML content
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to fetch URL: {response.status_code}")
        return

    html = response.text

    # Step 2: Parse HTML into DOM
    soup = BeautifulSoup(html, "html.parser")

    # Step 3: Recursive function to print tree
    def print_tree(node, indent=0, depth=0):
        if depth > max_depth:
            return
        prefix = " " * (indent * 2)
        if isinstance(node, Tag):
            print(f"{prefix}{node.name}")
            for child in node.children:
                print_tree(child, indent + 1, depth + 1)
        elif isinstance(node, NavigableString):
            text = node.strip()
            if text:
                print(f"{prefix}#text: {text[:30]}")  # Show first 30 chars of text

    # Step 4: Print the tree starting from <html>
    html_tag = soup.find("html")
    if html_tag:
        print_tree(html_tag)
    else:
        print_tree(soup)  # fallback if <html> is missing

# Example usage
url = all_resume_links[0]
fetch_and_print_dom(url)
# Out:
# html
#   head
#     base
#     meta
#     title
#       #text: Teradata DBA Resume Hoffman Es
#     meta
#       meta
#       meta
#       meta
#       meta
#   body
#     script
#       #text: (function (i, s, o, g, r, a, m
#     #text: Google tag (gtag.js)
#     script
#     script
#       #text: window.dataLayer = window.data
#     div
#     script
#       #text: (function (d, s, id) {
#
#     div
#       #text: <div class="page-loader page-l
#       header
#       section
#       section
#       #text: Modal
#       #text: <div class="modal fade resume-
#       #text: hubspot form
#       #text: <div class="hubspot-resume-for
#       div
#       div
#       div
#       div
#       div
#       #text: Scripts
#       noscript
#       script
#       script
#       script
#       script
#       script
#       script
#       #text: Developed By Revo Interactive
#   script
#     #text: _linkedin_partner_id = "479588
#   script
#     #text: (function(l) { if (!l){window.
#   noscript
#     img

# %%
def extract_post_body(url, target_class="single-post-body"):
    """
    Extracts the textual content from the main post body div.

    Args:
        url (str): Web page URL to scrape.
        target_class (str): Class name of the main content container.

    Returns:
        str: Clean text from the post body.
    """
    # Fetch HTML
    response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    response.raise_for_status()
    soup = BeautifulSoup(response.text, "html.parser")

    # Find the main content container
    container = soup.find("div", class_=target_class)
    if not container:
        raise ValueError(f"No <div> found with class '{target_class}'")

    # Extract all paragraphs and optional elements
    paragraphs = container.find_all(["p", "h1", "h2", "h3", "li"])
    
    # Clean and join text
    text_blocks = []
    for p in paragraphs:
        txt = p.get_text(separator=" ", strip=True)
        if txt:
            text_blocks.append(txt)

    # Join paragraphs into one big text
    full_text = "\n\n".join(text_blocks)
    return full_text


# Example usage
url = all_resume_links[0]
text = extract_post_body(url)
print(text[:1000])  # Preview first 1000 chars
with open("resume.txt", "w") as f:
    f.write(text)
# Out:
# OBJECTIVE Position where Database Designing and DBA skills and experience in database designing, administration and Management will add value in today’s challenging business and Information Technology. SUMMARY 8+ years of experience in IT and Teradata administration, designing database solutions with Architecture. 5+ Years of exclusive Production support and deploy of Teradata Patches, fixtures and DBQL settings. Experienced in archiving, restoring and recovering data on Teradata using ARC utility and TARA GUI. Excellent knowledge in moving database objects between Teradata systems and Teradata Database. Very well trained and experienced in scheduling backups and recovery of the entire EDW databases across various geographical locations for the business continuity and response time. Track record in Archiving and Recovering Down Amps Highly experienced in designing and testing Node fail over tests Highly knowledgeable in designing table DDL mechanisms for Automatic Data Protection Skill

# %%
def extract_post_body(url, target_class="single-post-body"):
    """
    Extracts clean textual content from the main post body div, avoiding duplicates.
    """
    response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    response.raise_for_status()
    soup = BeautifulSoup(response.text, "html.parser")

    container = soup.find("div", class_=target_class)
    if not container:
        raise ValueError(f"No <div> found with class '{target_class}'")

    # Extract only direct <p> tags and text nodes, not nested twice
    text_blocks = []
    for child in container.descendants:
        # Only consider direct visible text from paragraph-like tags
        if child.name in ["p", "h1", "h2", "h3", "li"]:
            txt = child.get_text(separator=" ", strip=True)
            if txt and txt not in text_blocks:  # avoid duplicate lines
                text_blocks.append(txt)

    # Join with line breaks
    full_text = "\n\n".join(text_blocks)
    return full_text


# Example usage
text = extract_post_body(url)
print(text)
with open("resume.txt", "w") as f:
    f.write(text)
# Out:
# OBJECTIVE Position where Database Designing and DBA skills and experience in database designing, administration and Management will add value in today’s challenging business and Information Technology. SUMMARY 8+ years of experience in IT and Teradata administration, designing database solutions with Architecture. 5+ Years of exclusive Production support and deploy of Teradata Patches, fixtures and DBQL settings. Experienced in archiving, restoring and recovering data on Teradata using ARC utility and TARA GUI. Excellent knowledge in moving database objects between Teradata systems and Teradata Database. Very well trained and experienced in scheduling backups and recovery of the entire EDW databases across various geographical locations for the business continuity and response time. Track record in Archiving and Recovering Down Amps Highly experienced in designing and testing Node fail over tests Highly knowledgeable in designing table DDL mechanisms for Automatic Data Protection Skilled in using Utility commands (TPA resets) for stopping and restarting Teradata Database. Efficient in housekeeping and maintaining database through regular cleanup of old logs, deleting old data, collecting statistics and tuning queries for efficient database running. Highly skilled in using tools for Managing Teradata Resources to minimize the occurrence of impeded performance, maximize throughput and manage of consumption of resources. Experienced in troubleshooting and analyzing problems like job hangs, slowdowns, inconsistent rows, revalidating headers for tables with RI constraints, PPIs and configuration Worked with Teradata field engineers in handling Teradata crash dumps. Handling efficient way of data and DDL backups and environment refreshes. Experienced in reading DBQL, PMON to identify monster queries and Hot Amps. Excellent planner for releases and Outage notifications. High expertise in cross database coding/design skills( Oracle, Teradata and SQLServer) Excellent track record in tuning ETL and SQL Jobs within the batch window Expert knowledge in DBS control and settings. Good coding and tuning skills using Teradata load utilities like Fastload and Teradata Parallel Transporter. Expert in UNIX scripts for Database extraction and filtering. Experienced using crontab utilities and shell scripting for scheduling weekly and nightly loads. Good hands on experience in coding and developing Autosys scripts. Designed the Utility testing environment for concurrent Loads in the Database (Teradata) box. Developed and deployed solutions that support integration of data in all environments - transactional as well as operational and analytical. Provided a solid basis for expediting transactions, streamlining operations, making optimal decisions, building large data warehouses, data marts. Implemented, Architected and Designed ETL story boards based on Hybrid model(Star and Snowflake) Experienced with supply chain management systems development, implementation and analysis. Excellent knowledge in Entity Relationship modeling and Physical database designing. Wrote SQL scripts for backend databases, custom stored procedures, macros. Enhanced and Customized load and back up scripts to the newly developed and in design projects. TECHNICAL SKILLS Operating Systems: Windows 95/98, Windows 2000, XP, UNIX, MS-DOS. Programming Languages: C, C++, Universe Basic, PERL, TCL, UNIX shell scripts. Tools: ERWIN Data Modeling, Rational Tools, Golden Gate Databases: Teradata 13.10/13.0.1// V12/6.2, Oracle 10g/9i, Universe DB, MS Access, SQL Server. PROFESSIONAL EXPERIENCE Confidential, Hoffman Estates, IL Teradata DBA Responsibilities: Responsible and involved in Setting up the Teradata database, users, Roles and Profiles. Applied data protection including Transient Journal, Fallback. Resolved deadlocks and DBQL maintenance creating an archive DBQL SYSTEM MGMT database. Defined Permanent space limits both at the database and user level for different business scenar ...
#
# OBJECTIVE
#
# Position where Database Designing and DBA skills and experience in database designing, administration and Management will add value in today’s challenging business and Information Technology.
#
# SUMMARY
#
# 8+ years of experience in IT and Teradata administration, designing database solutions with Architecture.
#
# 5+ Years of exclusive Production support and deploy of Teradata Patches, fixtures and DBQL settings.
#
# Experienced in archiving, restoring and recovering data on Teradata using ARC utility and TARA GUI.
#
# Excellent knowledge in moving database objects between Teradata systems and Teradata Database.
#
# Very well trained and experienced in scheduling backups and recovery of the entire EDW databases across various geographical locations for the business continuity and response time.
#
# Track record in Archiving and Recovering Down Amps
#
# Highly experienced in designing and testing Node fail over tests
#
# Highly knowledgeable in designing table DDL mechanisms for Automatic Data Protection
#
# Skilled in using Utility commands (TPA resets) for stopping and restarting Teradata Database.
#
# Efficient in housekeeping and maintaining database through regular cleanup of old logs, deleting old data, collecting statistics and tuning queries for efficient database running.
#
# Highly skilled in using tools for Managing Teradata Resources to minimize the occurrence of impeded performance, maximize throughput and manage of consumption of resources.
#
# Experienced in troubleshooting and analyzing problems like job hangs, slowdowns, inconsistent rows, revalidating headers for tables with RI constraints, PPIs and configuration
#
# Worked with Teradata field engineers in handling Teradata crash dumps.
#
# Handling efficient way of data and DDL backups and environment refreshes.
#
# Experienced in reading DBQL, PMON to identify monster queries and Hot Amps.
#
# Excellent planner for releases and Outage notifications.
#
# High expertise in cross database coding/design skills( Oracle, Teradata and SQLServer)
#
# Excellent track record in tuning ETL and SQL Jobs within the batch window
#
# Expert knowledge in DBS control and settings.
#
# Good coding and tuning skills using Teradata load utilities like Fastload and Teradata Parallel Transporter.
#
# Expert in UNIX scripts for Database extraction and filtering.
#
# Experienced using crontab utilities and shell scripting for scheduling weekly and nightly loads.
#
# Good hands on experience in coding and developing Autosys scripts.
#
# Designed the Utility testing environment for concurrent Loads in the Database (Teradata) box.
#
# Developed and deployed solutions that support integration of data in all environments - transactional as well as operational and analytical.
#
# Provided a solid basis for expediting transactions, streamlining operations, making optimal decisions, building large data warehouses, data marts.
#
# Implemented, Architected and Designed ETL story boards based on Hybrid model(Star and Snowflake)
#
# Experienced with supply chain management systems development, implementation and analysis.
#
# Excellent knowledge in Entity Relationship modeling and Physical database designing.
#
# Wrote SQL scripts for backend databases, custom stored procedures, macros. Enhanced and Customized load and back up scripts to the newly developed and in design projects.
#
# TECHNICAL SKILLS
#
# Operating Systems: Windows 95/98, Windows 2000, XP, UNIX, MS-DOS.
#
# Programming Languages: C, C++, Universe Basic, PERL, TCL, UNIX shell scripts.
#
# Tools: ERWIN Data Modeling, Rational Tools, Golden Gate
#
# Databases: Teradata 13.10/13.0.1// V12/6.2, Oracle 10g/9i, Universe DB, MS Access, SQL Server.
#
# PROFESSIONAL EXPERIENCE
#
# Confidential, Hoffman Estates, IL
#
# Teradata DBA
#
# Responsibilities:
#
# Responsible and involved in Setting up the Teradata database, users, Roles and Profiles.
#
# Applied data protection including Transient Journal, Fallback. Resolved deadlocks and DBQL maintenance creating an archive DBQL SYSTEM MGMT database.
#
# Defined Permanent space limits both at the database and user level for different business scenarios.
#
# Configured DBS control settings and MaxLoad AWT, MaxLoadTasks, DBQLFlushRate and system fields and other Performance fields like MaxParseTreeSegs.
#
# Took crash dumps and TSETs for the Teradata technology to analyze for certain crashes.
#
# Highly experienced in working with Teradata support team for Opening and tracking incidents for Teradata issues or any upgrades.
#
# Designed Security model based on the business model and enforced the security through roles.
#
# Worked with Teradata System Engineers and Support team to fix Node level issue.
#
# Installed patches to BAR server and Viewpoint.
#
# Developed statistics macros and automated to run based on the frequency.
#
# Used Dataflux tool for data profiling, data patterns and analyzing data for designing right Primary Indexes.
#
# Defined account IDs, priority scheduler performance groups, and system date and time substitution variables in user and profile definitions.
#
# Configured the TDWM and customized for the Sears’s business model.
#
# Experienced in Loading, archiving and restoring data Duties also involved are storage optimization, performance tuning, monitoring, UNIX shell scripting, and physical and logical database design.
#
# Controlled and tracked access to Teradata Database by granting and revoking privileges.
#
# Implemented Teradata protection features Table design and index selection Table implementations, maintenance, and backup, Problem support, Workload monitoring and control, Policies, procedures and guidelines that govern the Teradata environment
#
# Involved in SQL code review, Developer and user support and training, Capacity planning, System software testing and benchmarking and Support and coordination during hardware upgrades
#
# Designed DDLs and efficient PIs along with Identity Keys for efficient data distribution
#
# Assisted Developers with coding and effective Join issues
#
# Responsible for Backups every night after Major loads.
#
# Allocated spaces to the users, controlled Spool spaces and assigning of table spaces
#
# Planned the releases, monitored performance and reported to Teradata for further technical issues.
#
# Explained Users by showing Viewpoint about their inefficient queries
#
# Involved with Teradata to deploy patches, install, fix and figured out the settings.
#
# Applied DBQL settings to the business and application standards.
#
# Environment: Teradata 13.10, Teradata Administrator, Teradata SQL Assistant, Teradata Viewpoint, BTEQ, MLOAD, TPT, ARCHMAIN, TASM, Netbackup, TARA GUI, UNIX, Shell scripts.
#
# Confidential, Riverwoods, IL
#
# Involved in Setting up the Teradata database, Created databases and users, Allocated perm and spool space
#
# Applied data protection including Transient Journal, Fallback. Resolved deadlocks and involved in Granting and revoke security privileges.
#
# Defined Permanent space limits both at the database and user level.
#
# Created users, databases, roles, profiles and accounts.
#
# Established logon security, including external authentication.
#
# Implemented Teradata protection features Table design and index selection Table implementations, maintenance, and backup, Problem support, Workload monitoring and control, Policies, procedures and guidelines that govern the Teradata environment, SQL code review, Developer and user support and training, Capacity planning, System software testing and benchmarking and Support and coordination during hardware upgrades
#
# Hand coded Teradata SQL queries in Teradata CLI stage, Written Macros, Stored Procedures, triggers in Teradata. Extracted valid data to avoid overhead and Designed Test cases and Error codes and involved in testing the data stage Jobs before running in Pre-Prod, also helped ETL Developers in Understanding Data Models, identifying the various relationships among the tables in the Model. Written the best of Programming Logic to serve the BEST purpose.
#
# Developed Data Extractions which includes Unit and System Testing of all the Extractions. Involved in Reporting the Data and its Quality Issues to Profile team.
#
# Developed SQL Scripts in Teradata, Tuned Tpump jobs to avoid deadlocks.
#
# Ran DBQL and Explains to see the in depth frame of the query behavior
#
# Developed trend charts to monitor defect levels in databases in order to maintain statistical control of the business and site systems
#
# Developed Quality Stage macros to run in batch during specific times of the day.
#
# Expert in employing Total Quality Management with data modeling and RDBMS concepts in managing data quality and clean up efforts.
#
# Implemented triggers to monitor restricted tables and database access
#
# Involved in ETL Architecture from Source data flow to Target loading
#
# Designed high volume tables with efficient Primary Indexes and Primary Partition Indexes.
#
# Designed ICD system which is a common interface between teams for data communication
#
# Acted as the primary focal point of Contact for the IBI team for both business and technical support.
#
# Coded UNIX scripts for Database extraction and filtering.
#
# Responsible for Schema comparison and DDL validation.
#
# Designed ETL version of data model for the developers to understand the modeling from the developed logical and physical models.
#
# Environment: Teradata V2R6/12, TASM, Teradata Administrator, Teradata SQL Assistant, Teradata Manager, BTEQ, PMON, MLOAD, ARCHMAIN, UNIX, LINUX SUSE, Shell scripts.
#
# Confidential, Seattle, WA
#
# Teradata Application DBA
#
# Defined relationships as the identifying and non-identifying relationships ensuring integrity constraints.
#
# Designed and Architected ETL Preprocess system to capture delta loads.
#
# Responsible in Troubleshooting and releasing Mloads in different phases and restart scenarios.
#
# Wrote UNIX shell scripts for initialization process, scheduling and control mechanism.
#
# Supported the platform along with patches.
#
# Wrote queries which are resource hog and fine tuned for performance
#
# Excellent team player and complied to security
#
# Tutored developers regarding the PIs and Optimizer behavior about different queries.
#
# Developed sql scripts to identify data anomalies, complex data validation and for data cleansing purpose.
#
# Hand coded Teradata SQL queries in Teradata CLI stage, Written Macros, Stored Procedures, triggers in Teradata. Extracted valid data to avoid overhead and Designed Test cases and Error codes and involved in testing the data stage Jobs before running in Pre-Prod, also helped ETL
#
# Interacted with Business Units and Analysts to cleanse the data and match the Operating Standards.
#
# Used rich experience of database querying in Performance tuning of ETL Jobs and embedded SQL queries in OCI, CLI, Mutliload, Tpump and SQL-Loader.
#
# Imported and Exported Repositories cross projects.
#
# Prepared functional and technical specifications for the preprocess system.
#
# Highly technical competent in all phases of application systems
#
# Designed the Utility testing environment for concurrent Loads on the Teradata box.
#
# Created efficient hash tables for referential Integrity and Lookup purposes for validation and referential purpose.
#
# Experienced in writing SQL scripts for populating new fields added to tables on a one-shot basis and solving the problem associated with slowly-changing dimension for one of the dimension tables.
#
# Involved in performing unit testing and integration testing the individual and extract-transform-load jobs in sequence respectively.
#
# Analyzed the Data Sources in identifying data anomalies patterns value ranges. Wrote SQL scripts for accomplishing the same.
#
# Compiled and debugging the Jobs based on the Errors.
#
# Wrote shell scripts for scheduling the ETL process.
#
# Environment: Teradata V2R5/R6, TASM, TPT, Teradata Administrator, Teradata SQL Assistant, Teradata Manager, BTEQ, PMON, MLOAD, ARCHMAIN, Net vault, Erwin Designer, UNIX, Shell scripts.
#
# Confidential, Atlanta, GA
#
# Teradata/ETL Developer
#
# Responsible for delivering project timeline associated with the developer deliverables.
#
# Designing and developing relational and dimensional models in Framework Manager.
#
# Used different Teradata utilities on UNIX and Mainframes (COBOL) environment.
#
# Responsible to gather requirements from business users and format them according to the business needs, model the requirements to match the current architecture and assign it to the team
#
# Educated the team on how to do the performance tuning on complex queries with efficiency of MULTI-TABLE concept, Join Index, PPI, Partitioning PPI, Secondary Index mechanism, backup and recovery, day-to-day request such as altering a table, capacity planning, general SQL tuning and skew factor.
#
# Expert in physical database design, logical modelling and development of pro-active processes for monitoring capacity and performance.
#
# Supported other ongoing projects: Software Upgrade project from Teradata V2R6.2 to V12.
#
# Highly proficient in writing Teradata load and export scripts like BTEQ, MLoad, FLoad and Fast Export.
#
# Responsible for creating Procedures and Jobs on Mainframes using JCL, to run various scripts like BTEQ, FLOAD, MLOAD and FEXPORT.
#
# Created COBOL copy books to check the format and data before sending the file to the clients.
#
# Used version control tool like Endeavor to elevate components to production environment.
#
# Educated the team on how to utilise the teradata visual tools like Teradata Manager, Database query language (DBQL), TDQM, Visual explain etc.,
#
# Implemented a process from Development life cycle to the production implementation including naming conventions, environment prefix etc and trained the team accordingly.
#
# Optimised high volume tables (Including collection tables) in teradata using various join index techniques, secondary indexes, join strategies and hash distribution methods.
#
# Implemented different kinds of purging techniques to free up space in certain teradata databases and to remove orphan records from collection tables.
#
# Trained off-shore team (four) and on-site team (three) on teradata architecture, usage of Bteq in UNIX environment and usage of MLoad, FLoad, Fast Export.
#
# Extensively used MLoad, FLoad and Fast Export Teradata tools both in ETL and UNIX scripts for high volume flat files.
#
# Created a Generic BTEQ script to load the data into various target tables from flat files using control table mechanism.
#
# Using PERL, created a script which generates MLoad script on the fly based on the table name supplied as a parameter. This has reduced the manual intervention in case of new table added in the database.
#
# Implemented data export from one environment to another environment using Fast Export and Fast Load. All that the scripts needs is table name, environment to export, environment to import and user credentials. This gives flexibility of importing data from production to test and to development as when the environments require fresh data.
#
# Faster incoming file process automated to loading into teradata staging using BTEQ, Fast Load and then loaded into MLoad by concatenating files on the basis of table name.
#
# The technologies used in processes are Teradata, oracle, DB2, UNIX and Mainframes.
#
# Extensively worked on teradata performance optimization and brought down the queries to seconds or minutes from spool out and never ending queries by using various teradata optimization strategies.

# %%
def extract_post_body(url, target_class="single-post-body", min_word_threshold=200):
    """
    Extracts clean textual content from the main post body div,
    skipping oversized unstructured text blocks.
    """
    response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    response.raise_for_status()
    soup = BeautifulSoup(response.text, "html.parser")

    container = soup.find("div", class_=target_class)
    if not container:
        raise ValueError(f"No <div> found with class '{target_class}'")

    text_blocks = []
    skipped_blocks = []

    for child in container.descendants:
        if child.name in ["p", "h1", "h2", "h3", "li"]:
            txt = child.get_text(separator=" ", strip=True)
            if not txt:
                continue

            word_count = len(txt.split())
            has_line_breaks = "\n" in txt

            # Skip overly long single-line text blobs
            if word_count > min_word_threshold and not has_line_breaks:
                skipped_blocks.append(txt[:120] + "...")
                continue

            # Avoid duplicates
            if txt not in text_blocks:
                text_blocks.append(txt)

    full_text = "\n\n".join(text_blocks)

    print(f"✅ Extracted {len(text_blocks)} valid blocks, 🧹 skipped {len(skipped_blocks)} noisy ones.")
    return full_text, skipped_blocks


# Example usage
text, skipped = extract_post_body(url)

print("\n--- CLEANED TEXT PREVIEW ---\n")
print(text[:600])

print("\n--- SKIPPED BLOCKS (for debugging) ---\n")
for s in skipped:
    print("-", s[:200])

with open("resume.txt", "w") as f:
    f.write(text)
# Out:
# ✅ Extracted 141 valid blocks, 🧹 skipped 1 noisy ones.
#
# --- CLEANED TEXT PREVIEW ---
#
# OBJECTIVE
#
# Position where Database Designing and DBA skills and experience in database designing, administration and Management will add value in today’s challenging business and Information Technology.
#
# SUMMARY
#
# 8+ years of experience in IT and Teradata administration, designing database solutions with Architecture.
#
# 5+ Years of exclusive Production support and deploy of Teradata Patches, fixtures and DBQL settings.
#
# Experienced in archiving, restoring and recovering data on Teradata using ARC utility and TARA GUI.
#
# Excellent knowledge in moving database objects between Teradata systems and T
#
# --- SKIPPED BLOCKS (for debugging) ---
#
# - OBJECTIVE Position where Database Designing and DBA skills and experience in database designing, administration and Mana...

# %%
import re
import requests
import json
from bs4 import BeautifulSoup

def normalize_breaks(soup):
    """
    Convert <br> tags to newline text nodes so .get_text() uses them.
    """
    for br in soup.find_all("br"):
        br.replace_with("\n")

def clean_whitespace(text):
    # Collapse multiple spaces but keep line breaks
    # remove leading/trailing whitespace on each line
    lines = [ln.strip() for ln in text.splitlines()]
    # drop empty lines at ends
    while lines and lines[0] == "":
        lines.pop(0)
    while lines and lines[-1] == "":
        lines.pop()
    return "\n".join([re.sub(r'\s+', ' ', ln) for ln in lines])

def extract_post_body_safe(url,
                           target_class=None,
                           class_regex=None,
                           allow_fallback=True,
                           debug=False):
    """
    Robustly extract text from the main post container.

    Args:
        url (str)
        target_class (str): exact class name to search for (preferred)
        class_regex (str): regex to match classes like "post-content|entry-content"
        allow_fallback (bool): if True, try to auto-detect the largest text container
        debug (bool): prints debugging info

    Returns:
        dict: {
            "full_text": str,           # joined paragraph text (with double-newlines between p tags)
            "p_texts": [str,...],       # list of p-level texts captured
            "container_text": str,      # container.get_text() (cleaned)
            "missing_excerpt": str,     # excerpt of text present in container_text but not in concatenated p_texts (if any)
            "warnings": [str,...]       # list of warnings (e.g., JS-rendered suspicion)
        }
    """
    headers = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)"}
    resp = requests.get(url, headers=headers, timeout=20)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    # Normalize <br> tags
    normalize_breaks(soup)

    container = None
    if target_class:
        container = soup.find("div", class_=target_class)
    if not container and class_regex:
        container = soup.find("div", class_=re.compile(class_regex))
    if not container and allow_fallback:
        # Fallback: choose the div with largest text content
        divs = soup.find_all("div")
        if divs:
            container = max(divs, key=lambda d: len(d.get_text(strip=True)))
    if not container:
        raise ValueError("Could not find a suitable container. Try specifying target_class or class_regex.")

    # Capture the raw container text and normalize whitespace
    raw_container_text = container.get_text(separator="\n", strip=True)
    container_text = clean_whitespace(raw_container_text)

    # Find all paragraph-like tags inside container
    paragraph_tags = container.find_all(["p", "article", "div"], recursive=True)
    # We use a filter: we keep those tags which have some textual content and are likely paragraphs.
    p_texts = []
    for idx, tag in enumerate(paragraph_tags):
        # Skip tags that are empty or just whitespace/newlines
        txt = " ".join(tag.stripped_strings)  # joins text pieces including nested spans
        txt = txt.strip()
        if not txt:
            continue

        # Heuristic: avoid grabbing container-level big dumps repeated (optional)
        # (But by default we keep everything; you can add thresholds if needed)
        p_texts.append(clean_whitespace(txt))

    # Deduplicate while preserving order
    seen = set()
    unique_p_texts = []
    all_p_texts = []
    for t in p_texts:
        if t not in seen:
            unique_p_texts.append(t)
            seen.add(t)
        all_p_texts.append(t)
    # Join paragraphs with double newlines
    joined_p = "\n\n".join(unique_p_texts)

    # Compare counts to detect missing parts
    warnings = []
    # If container_text is substantially longer than joined_p, maybe some text is outside p-tags or JS-rendered
    container_words = len(container_text.split())
    joined_words = len(re.sub(r'\s+', ' ', joined_p).split()) if joined_p else 0

    missing_excerpt = ""
    if container_words > joined_words + 20:  # allow small differences
        # compute missing by naive subtraction — find container text not in joined_p
        if joined_p:
            # remove matched paragraph fragments from container_text
            temp = container_text
            for piece in unique_p_texts:
                temp = temp.replace(piece, "")
            missing_excerpt = temp.strip()[:800]  # give first 800 chars of leftover
        else:
            missing_excerpt = container_text[:800]

        if missing_excerpt:
            warnings.append("Container has additional text not captured by paragraph-like tags. See missing_excerpt.")
        else:
            warnings.append("Detected difference in counts but couldn't compute missing excerpt.")

    # Detect likely JS-rendered content (very common cause)
    # If the original HTML contains obvious placeholders or empty content but the container_text is short, warn.
    if "<script" in resp.text.lower() and (container_words == 0 or joined_words == 0):
        warnings.append("Page might be JS-rendered. Try using Playwright or Selenium to render JS before extraction.")

    if debug:
        print("===== DEBUG INFO =====")
        print("URL:", url)
        print("Container chosen tag/classes:", container.name, container.get("class"))
        print("Container words:", container_words)
        print("Paragraph-like nodes found (count):", len(paragraph_tags))
        print("Captured paragraph count:", len(unique_p_texts))
        print("Joined paragraph words:", joined_words)
        print("Warnings:", warnings)
        if missing_excerpt:
            print("Missing excerpt (first 400 chars):")
            print(missing_excerpt[:400])
        print("======================")

    return {
        "full_text": joined_p,
        "p_texts": unique_p_texts,
        "all_p_texts": all_p_texts,
        "container_text": container_text,
        "missing_excerpt": missing_excerpt,
        "warnings": warnings
    }



result = extract_post_body_safe(
url,
class_regex=r"(single-post-body|post-content|entry-content|article-body)",
debug=True
)

print("=== Full text preview ===")
print(result["full_text"][:1200])

if result["missing_excerpt"]:
    print("\n=== Missing excerpt (possible lost text) ===")
    print(result["missing_excerpt"])

if result["warnings"]:
    print("\n=== Warnings ===")
    for w in result["warnings"]:
        print("-", w)

with open("resume.json", "w") as f:
    f.write(json.dumps(result, indent=4))
# Out:
# ===== DEBUG INFO =====
# URL: https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/628272-teradata-dba-resume-hoffman-estates-il-2
# Container chosen tag/classes: div ['single-post-body']
# Container words: 2475
# Paragraph-like nodes found (count): 24
# Captured paragraph count: 20
# Joined paragraph words: 2606
# Warnings: []
# ======================
# === Full text preview ===
# OBJECTIVE Position where Database Designing and DBA skills and experience in database designing, administration and Management will add value in today’s challenging business and Information Technology. SUMMARY 8+ years of experience in IT and Teradata administration, designing database solutions with Architecture. 5+ Years of exclusive Production support and deploy of Teradata Patches, fixtures and DBQL settings. Experienced in archiving, restoring and recovering data on Teradata using ARC utility and TARA GUI. Excellent knowledge in moving database objects between Teradata systems and Teradata Database. Very well trained and experienced in scheduling backups and recovery of the entire EDW databases across various geographical locations for the business continuity and response time. Track record in Archiving and Recovering Down Amps Highly experienced in designing and testing Node fail over tests Highly knowledgeable in designing table DDL mechanisms for Automatic Data Protection Skilled in using Utility commands (TPA resets) for stopping and restarting Teradata Database. Efficient in housekeeping and maintaining database through regular cleanup of old logs, deleting old data, coll

# %%
def normalize_breaks(soup):
    """Convert <br> tags to newline text nodes so .get_text() uses them."""
    for br in soup.find_all("br"):
        br.replace_with("\n")

def clean_whitespace(text):
    lines = [ln.strip() for ln in text.splitlines()]
    while lines and lines[0] == "":
        lines.pop(0)
    while lines and lines[-1] == "":
        lines.pop()
    return "\n".join([re.sub(r'\s+', ' ', ln) for ln in lines])

def extract_post_body_safe(url,
                           target_class=None,
                           class_regex=None,
                           allow_fallback=True,
                           debug=False):
    """
    Extracts text and structure (<p>, <ul>, <li>) from the main post container.
    """
    headers = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64)"}
    resp = requests.get(url, headers=headers, timeout=20)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    normalize_breaks(soup)

    container = None
    if target_class:
        container = soup.find("div", class_=target_class)
    if not container and class_regex:
        container = soup.find("div", class_=re.compile(class_regex))
    if not container and allow_fallback:
        divs = soup.find_all("div")
        if divs:
            container = max(divs, key=lambda d: len(d.get_text(strip=True)))
    if not container:
        raise ValueError("Could not find a suitable container.")

    raw_container_text = container.get_text(separator="\n", strip=True)
    container_text = clean_whitespace(raw_container_text)

    # Preserve structure: paragraphs, unordered lists and list items
    structured_content = []
    for element in container.find_all(["p", "ul"], recursive=True):
        if element.name == "p":
            text = clean_whitespace(" ".join(element.stripped_strings))
            if text:
                structured_content.append({
                    "type": "p",
                    "text": text
                })
        elif element.name == "ul":
            items = []
            for li in element.find_all("li", recursive=False):
                li_text = clean_whitespace(" ".join(li.stripped_strings))
                if li_text:
                    items.append(li_text)
            if items:
                structured_content.append({
                    "type": "ul",
                    "items": items
                })

    # Join paragraphs for convenience
    joined_p = "\n\n".join(
        [block["text"] for block in structured_content if block["type"] == "p"]
    )

    container_words = len(container_text.split())
    joined_words = len(joined_p.split()) if joined_p else 0

    warnings = []
    missing_excerpt = ""
    if container_words > joined_words + 20:
        temp = container_text
        for block in structured_content:
            if block["type"] == "p":
                temp = temp.replace(block["text"], "")
            elif block["type"] == "ul":
                for item in block["items"]:
                    temp = temp.replace(item, "")
        missing_excerpt = temp.strip()[:800]
        if missing_excerpt:
            warnings.append("Container has additional text not captured by structured tags.")
    if "<script" in resp.text.lower() and (container_words == 0 or joined_words == 0):
        warnings.append("Page might be JS-rendered. Try using Playwright or Selenium.")

    if debug:
        print("===== DEBUG INFO =====")
        print("Container:", container.get("class"))
        print("Captured paragraphs:", sum(1 for b in structured_content if b["type"] == "p"))
        print("Captured lists:", sum(1 for b in structured_content if b["type"] == "ul"))
        print("Warnings:", warnings)
        print("======================")

    return {
        "url":url,
        "structured_content": structured_content,
        "full_text": joined_p,
        "container_text": container_text,
        "missing_excerpt": missing_excerpt,
        "warnings": warnings
    }

# Example usage
result = extract_post_body_safe(
    all_resume_links[79],
    class_regex=r"(single-post-body|post-content|entry-content|article-body)",
    debug=True
)

# Print preview
for block in result["structured_content"][:5]:
    if block["type"] == "p":
        print(f"PARA: {block['text'][:100]}")
    elif block["type"] == "ul":
        print(f"LIST: {block['items']}")

# Save to JSON
with open("post_content_79.json", "w") as f:
    f.write(json.dumps(result, indent=4, ensure_ascii=False))
# Out:
# ===== DEBUG INFO =====
# Container: ['single-post-body']
# Captured paragraphs: 33
# Captured lists: 6
# Warnings: []
# ======================
# PARA: SUMMARY Over 7 years of experience in the field of Information Technology, this includes pioneering
# PARA: SUMMARY
# LIST: ['Over 7 years of experience in the field of Information Technology, this includes pioneering work in business Analysis, requirements, development, testing, implementing and support of Hyperion system applications and Client/Server projects using industry accepted methodologies and procedures.', 'Extensive experience in the development, design, analysis and Implementation of various applications using Hyperion System 9/11, Hyperion Essbase 11.x/9.X, Hyperion Planning 11.x/9.x', 'Strong experience in the design, development, and administration of Hyperion applications.', 'Experience in performing upgrade, migration. Production support and database backups, Performance tuning and Optimization of Hyperion applications.', 'Actively involved in interacting with the users and gathering the requirements for a new implementation and enhancing existing Applications.', 'Expertise in Life Cycle Management (LCM) to migrate the artifacts from source to target server for all Hyperion products and DB export/Import.', 'Extensive experience in building Financial Budgeting & Forecasting, Contribution Margin, Sales, profit margin, variance calculations, exchange rate calculation application with Hyperion Planning (Forms, Security, Metadata Maintenance, Business Rules and Essbase Excel Add - In), and Reports.', 'Excellent proficiency in both Star Schema and Snow-Flake Schema data modeling techniques.', 'Skilled in Partitioning, automation, optimization and performance tuning of Essbase application data/metadata processing, upgrading, testing and migrating of cubes in different environment.', 'Expert in installing and configuring Hyperion applications across different platforms.', 'Extensive experience in writing scripts using ESSCMD and MaxL.', 'Expert Level experience in Hyperion Reports, Essbase Excel Spreadsheet Add-In and Smart view.', 'Experienced in Hyperion Data management tools like ODI & FDQM.', 'Versatile team player with excellent analytical, presentation and interpersonal skills with an aptitude to learn new technologies.', 'Extensive knowledge in Oracle, SQL Server, MS Access.']
# PARA: TECHNICAL SKILLS
# PARA: EPM: Hyperion System 11.x/9.x/7.x

# %%
import json

# %% [markdown]
# ### Important

# %%
class Experience(BaseModel):
    job_role: str
    responsibilities: List[str]
    environment: Optional[str] = None

class Resume(BaseModel):
    professional_summary: List[str]
    technical_skills: List[str]
    experiences: List[Experience]

    
def normalize_breaks(soup):
    """Convert <br> tags to newline text nodes so .get_text() uses them."""
    for br in soup.find_all("br"):
        br.replace_with("\n")

def clean_whitespace(text):
    lines = [ln.strip() for ln in text.splitlines()]
    while lines and lines[0] == "":
        lines.pop(0)
    while lines and lines[-1] == "":
        lines.pop()
    return "\n".join([re.sub(r'\s+', ' ', ln) for ln in lines])

def extract_post_body_safe(url,
                           target_class=None,
                           class_regex=None,
                           allow_fallback=True,
                           debug=False,
                           min_word_threshold=120):
    """
    Extracts structured content (<p>, <ul>, <li>, .media-body job roles)
    from the main post container, skipping oversized text blocks.
    """
    headers = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64)"}
    resp = requests.get(url, headers=headers, timeout=20)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    normalize_breaks(soup)

    # Identify container
    container = None
    if target_class:
        container = soup.find("div", class_=target_class)
    if not container and class_regex:
        container = soup.find("div", class_=re.compile(class_regex))
    if not container and allow_fallback:
        divs = soup.find_all("div")
        if divs:
            container = max(divs, key=lambda d: len(d.get_text(strip=True)))
    if not container:
        raise ValueError("Could not find a suitable container.")

    raw_container_text = container.get_text(separator="\n", strip=True)
    container_text = clean_whitespace(raw_container_text)

    structured_content = []
    skipped_blocks = []  # 🔹 Track skipped text blocks

    # 1️⃣ Handle .media-body blocks
    for media in container.find_all("div", class_=re.compile(r"media-body")):
        role_data = {}
        job_title_tag = media.find("h3")
        if job_title_tag:
            role_data["job_role"] = clean_whitespace(job_title_tag.get_text())

        sub_blocks = []
        for child in media.find_all(["p", "ul"], recursive=False):
            if child.name == "p":
                text = clean_whitespace(" ".join(child.stripped_strings))
                # 🚫 Skip overly long text blocks
                if len(text.split()) > min_word_threshold:
                    skipped_blocks.append(text[:120] + "...")
                    continue
                if text:
                    sub_blocks.append({"type": "p", "text": text})
            elif child.name == "ul":
                items = []
                for li in child.find_all("li", recursive=False):
                    li_text = clean_whitespace(" ".join(li.stripped_strings))
                    # 🚫 Skip overly long list items
                    if len(li_text.split()) > min_word_threshold:
                        skipped_blocks.append(li_text[:120] + "...")
                        continue
                    if li_text:
                        items.append(li_text)
                if items:
                    sub_blocks.append({"type": "ul", "items": items})
        if sub_blocks or "job_role" in role_data:
            role_data["content"] = sub_blocks
            structured_content.append(role_data)

    # 2️⃣ Handle normal paragraphs and lists not under media-body
    for element in container.find_all(["p", "ul"], recursive=True):
        if element.find_parent("div", class_=re.compile(r"media-body")):
            continue  # already captured above

        if element.name == "p":
            text = clean_whitespace(" ".join(element.stripped_strings))
            # 🚫 Skip overly long text blocks
            if len(text.split()) > min_word_threshold:
                skipped_blocks.append(text[:120] + "...")
                continue
            if text:
                structured_content.append({"type": "p", "text": text})

        elif element.name == "ul":
            items = []
            for li in element.find_all("li", recursive=False):
                li_text = clean_whitespace(" ".join(li.stripped_strings))
                # 🚫 Skip overly long list items
                if len(li_text.split()) > min_word_threshold:
                    skipped_blocks.append(li_text[:120] + "...")
                    continue
                if li_text:
                    items.append(li_text)
            if items:
                structured_content.append({"type": "ul", "items": items})

    # Join all paragraph text for convenience
    joined_p = "\n\n".join(
        [b["text"] for b in structured_content if b.get("type") == "p"]
    )

    container_words = len(container_text.split())
    joined_words = len(joined_p.split()) if joined_p else 0

    warnings = []
    missing_excerpt = ""
    if container_words > joined_words + 20:
        temp = container_text
        for block in structured_content:
            if block.get("type") == "p":
                temp = temp.replace(block["text"], "")
            elif block.get("type") == "ul":
                for item in block["items"]:
                    temp = temp.replace(item, "")
            elif "job_role" in block:
                temp = temp.replace(block["job_role"], "")
                for sub in block.get("content", []):
                    if sub.get("type") == "p":
                        temp = temp.replace(sub["text"], "")
                    elif sub.get("type") == "ul":
                        for item in sub["items"]:
                            temp = temp.replace(item, "")
        missing_excerpt = temp.strip()[:800]
        if missing_excerpt:
            warnings.append("Container has additional text not captured by structured tags.")

    if "<script" in resp.text.lower() and (container_words == 0 or joined_words == 0):
        warnings.append("Page might be JS-rendered.")

    if debug:
        print("===== DEBUG INFO =====")
        print("Container classes:", container.get("class"))
        print("Job roles found:", sum(1 for b in structured_content if "job_role" in b))
        print("Paragraphs:", sum(1 for b in structured_content if b.get("type") == "p"))
        print("Lists:", sum(1 for b in structured_content if b.get("type") == "ul"))
        print("Skipped blocks:", len(skipped_blocks))
        print("Warnings:", warnings)
        print("======================")

    return {
        "structured_content": structured_content,
        "full_text": joined_p,
        "container_text": container_text,
        "missing_excerpt": missing_excerpt,
        "skipped_blocks": skipped_blocks,
        "warnings": warnings
    }
url = "https://www.hireitpeople.com/resume-database/77-oracle-resumes/113390-sr-oracle-developer-data-architect-resume-ny"
# Example usage
result = extract_post_body_safe(
    url,
    class_regex=r"(single-post-body|post-content|entry-content|article-body)",
    debug=True
)

# --- Preview ---
for block in result["structured_content"]:
    if "job_role" in block:
        print(f"\nJOB ROLE: {block['job_role']}")
        for sub in block["content"]:
            if sub["type"] == "p":
                print("  DESC:", sub["text"][:80])
            elif sub["type"] == "ul":
                print("  BULLETS:", sub["items"])
    elif block.get("type") == "p":
        print("PARA:", block["text"][:100])
    elif block.get("type") == "ul":
        print("LIST:", block["items"])

with open("post_content_79_2.json", "w") as f:
    f.write(json.dumps(result, indent=4, ensure_ascii=False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 class Experience(BaseModel):
#       2     job_role: str
#       3     responsibilities: List[str]
#
# NameError: name 'BaseModel' is not defined

# %%
import requests
from bs4 import BeautifulSoup
import re
import json

def normalize_breaks(soup):
    """Convert <br> tags to newline text nodes so .get_text() uses them."""
    for br in soup.find_all("br"):
        br.replace_with("\n")

def clean_whitespace(text):
    lines = [ln.strip() for ln in text.splitlines()]
    while lines and lines[0] == "":
        lines.pop(0)
    while lines and lines[-1] == "":
        lines.pop()
    return "\n".join([re.sub(r'\s+', ' ', ln) for ln in lines])

def extract_post_body_safe(url,
                           target_class=None,
                           class_regex=None,
                           allow_fallback=True,
                           debug=False,
                           min_word_threshold=120):
    """
    Extracts structured content (<p>, <ul>, <li>, .media-body job roles)
    from the main post container and media-body elements from entire page.
    """
    headers = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64)"}
    resp = requests.get(url, headers=headers, timeout=20)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    normalize_breaks(soup)

    # Identify main content container
    container = None
    if target_class:
        container = soup.find("div", class_=target_class)
    if not container and class_regex:
        container = soup.find("div", class_=re.compile(class_regex))
    if not container and allow_fallback:
        divs = soup.find_all("div")
        if divs:
            container = max(divs, key=lambda d: len(d.get_text(strip=True)))
    if not container:
        raise ValueError("Could not find a suitable container.")

    raw_container_text = container.get_text(separator="\n", strip=True)
    container_text = clean_whitespace(raw_container_text)

    structured_content = []
    skipped_blocks = []
    processed_elements = set()

    # 🔥 KEY CHANGE: Search for media-body in entire soup, not just container
    for media in soup.find_all("div", class_=re.compile(r"media-body")):
        role_data = {}
        
        # Look for job title - check h3 first, then other headings
        job_title_tag = media.find("h3")
        if not job_title_tag:
            job_title_tag = media.find(["h1", "h2", "h4", "h5", "h6"])
        
        if job_title_tag:
            role_data["job_role"] = clean_whitespace(job_title_tag.get_text())
            processed_elements.add(job_title_tag)

        sub_blocks = []
        # Process all paragraphs and lists within this media-body
        for element in media.find_all(["p", "ul"]):
            if element in processed_elements:
                continue
                
            if element.name == "p":
                text = clean_whitespace(" ".join(element.stripped_strings))
                # Skip overly long text blocks
                if len(text.split()) > min_word_threshold:
                    skipped_blocks.append(text[:120] + "...")
                    continue
                if text:
                    sub_blocks.append({"type": "p", "text": text})
                    processed_elements.add(element)
            elif element.name == "ul":
                items = []
                for li in element.find_all("li", recursive=False):
                    li_text = clean_whitespace(" ".join(li.stripped_strings))
                    # Skip overly long list items
                    if len(li_text.split()) > min_word_threshold:
                        skipped_blocks.append(li_text[:120] + "...")
                        continue
                    if li_text:
                        items.append(li_text)
                if items:
                    sub_blocks.append({"type": "ul", "items": items})
                    processed_elements.add(element)

        # Only add if we have either a job role or content
        if sub_blocks or "job_role" in role_data:
            role_data["content"] = sub_blocks
            structured_content.append(role_data)
            # Mark all elements in this media-body as processed
            for element in media.find_all():
                processed_elements.add(element)

    # Now process content from the main container, skipping already processed elements
    for element in container.find_all(["p", "ul"]):
        if element in processed_elements:
            continue
            
        # Skip if this element is inside any media-body (already processed)
        if element.find_parent("div", class_=re.compile(r"media-body")):
            continue

        if element.name == "p":
            text = clean_whitespace(" ".join(element.stripped_strings))
            # Skip overly long text blocks
            if len(text.split()) > min_word_threshold:
                skipped_blocks.append(text[:120] + "...")
                continue
            if text:
                structured_content.append({"type": "p", "text": text})
                processed_elements.add(element)

        elif element.name == "ul":
            items = []
            for li in element.find_all("li", recursive=False):
                li_text = clean_whitespace(" ".join(li.stripped_strings))
                # Skip overly long list items
                if len(li_text.split()) > min_word_threshold:
                    skipped_blocks.append(li_text[:120] + "...")
                    continue
                if li_text:
                    items.append(li_text)
            if items:
                structured_content.append({"type": "ul", "items": items})
                processed_elements.add(element)

    # Join all paragraph text for convenience
    joined_p = "\n\n".join(
        [b["text"] for b in structured_content if b.get("type") == "p"]
    )

    container_words = len(container_text.split())
    joined_words = len(joined_p.split()) if joined_p else 0

    warnings = []
    missing_excerpt = ""
    if container_words > joined_words + 20:
        temp = container_text
        for block in structured_content:
            if block.get("type") == "p":
                temp = temp.replace(block["text"], "")
            elif block.get("type") == "ul":
                for item in block["items"]:
                    temp = temp.replace(item, "")
            elif "job_role" in block:
                temp = temp.replace(block["job_role"], "")
                for sub in block.get("content", []):
                    if sub.get("type") == "p":
                        temp = temp.replace(sub["text"], "")
                    elif sub.get("type") == "ul":
                        for item in sub["items"]:
                            temp = temp.replace(item, "")
        missing_excerpt = temp.strip()[:800]
        if missing_excerpt:
            warnings.append("Container has additional text not captured by structured tags.")

    if "<script" in resp.text.lower() and (container_words == 0 or joined_words == 0):
        warnings.append("Page might be JS-rendered.")

    if debug:
        print("===== DEBUG INFO =====")
        print("Container classes:", container.get("class"))
        print("Total media-body elements found:", len(soup.find_all("div", class_=re.compile(r"media-body"))))
        print("Job roles found:", sum(1 for b in structured_content if "job_role" in b))
        print("Paragraphs:", sum(1 for b in structured_content if b.get("type") == "p"))
        print("Lists:", sum(1 for b in structured_content if b.get("type") == "ul"))
        print("Skipped blocks:", len(skipped_blocks))
        print("Warnings:", warnings)
        
        # Debug media-body details
        media_bodies = soup.find_all("div", class_=re.compile(r"media-body"))
        for i, media in enumerate(media_bodies):
            h3 = media.find("h3")
            other_heading = media.find(["h1", "h2", "h4", "h5", "h6"])
            print(f"Media-body {i+1}:")
            print(f"  h3 found: {h3 is not None}")
            if h3:
                print(f"  h3 text: '{h3.get_text(strip=True)}'")
            elif other_heading:
                print(f"  Other heading found: '{other_heading.get_text(strip=True)}'")
            else:
                print(f"  No heading found")
        print("======================")

    return {
        "structured_content": structured_content,
        "full_text": joined_p,
        "container_text": container_text,
        "missing_excerpt": missing_excerpt,
        "skipped_blocks": skipped_blocks,
        "warnings": warnings
    }

# Example usage
url = "https://www.hireitpeople.com/resume-database/77-oracle-resumes/142742-oracle-pl-sql-developer-resume-portland-oregon"

result = extract_post_body_safe(
    url,
    class_regex=r"(single-post-body|post-content|entry-content|article-body)",
    debug=True
)

# --- Preview ---
print("\n" + "="*50)
print("EXTRACTED CONTENT PREVIEW")
print("="*50)
for i, block in enumerate(result["structured_content"]):
    if "job_role" in block:
        print(f"\n[{i}] JOB ROLE: {block['job_role']}")
        for sub in block.get("content", []):
            if sub["type"] == "p":
                print(f"    DESC: {sub['text'][:80]}{'...' if len(sub['text']) > 80 else ''}")
            elif sub["type"] == "ul":
                print(f"    BULLETS: {len(sub['items'])} items")
                for j, item in enumerate(sub['items'][:2]):  # Show first 2 bullets
                    print(f"      - {item[:60]}{'...' if len(item) > 60 else ''}")
    elif block.get("type") == "p":
        print(f"\n[{i}] PARA: {block['text'][:100]}{'...' if len(block['text']) > 100 else ''}")
    elif block.get("type") == "ul":
        print(f"\n[{i}] LIST: {len(block['items'])} items")
        for j, item in enumerate(block['items'][:2]):  # Show first 2 items
            print(f"      - {item[:60]}{'...' if len(item) > 60 else ''}")

# Save to file
with open("post_content_fixed.json", "w") as f:
    json.dumps(result, indent=4, ensure_ascii=False)

print(f"\nSaved results to post_content_fixed.json")
print(f"Total structured blocks extracted: {len(result['structured_content'])}")
# Out:
# ===== DEBUG INFO =====
# Container classes: ['single-post-body']
# Total media-body elements found: 1
# Job roles found: 1
# Paragraphs: 27
# Lists: 6
# Skipped blocks: 1
# Warnings: ['Container has additional text not captured by structured tags.']
# Media-body 1:
#   h3 found: True
#   h3 text: 'Oracle Pl/sql Developer Resume'
# ======================
#
# ==================================================
# EXTRACTED CONTENT PREVIEW
# ==================================================
#
# [0] JOB ROLE: Oracle Pl/sql Developer Resume
#
# [1] PARA: SUMMARY:
#
# [2] LIST: 20 items
#       - 8+ years of profound working experience in SQL, PL/SQL progr...
#       - Expertise in writing SQL queries, Views, Materialized views,...
#
# [3] PARA: TECHNICAL SKILLS:
#
# [4] PARA: Operating System: Windows 7/10, Linux, UNIX (Sun Solaris, HP-UX).
#
# [5] PARA: Oracle 12c/11g/10g/9i, MS: SQL Server.
#
# [6] PARA: Web Technologies: HTML, DHTML, Java Script, XML.
#
# [7] PARA: Languages: C, C++, SQL, PL/ SQL.
#
# [8] PARA: Scripting Languages: UNIX Shell Scripting
#
# [9] PARA: Database Tools: SQL*PLUS, TOAD, SQL*Tool, PL/SQL Developer
#
# [10] PARA: MS: Office (Access, Word, Excel, PowerPoint)
#
# [11] PARA: Version Control: CVS, SVN, GITHUB
#
# [12] PARA: Agile Tools/Methodologies: Jira, RTC, SCRUM
#
# [13] PARA: PROFESSIONAL EXPERIENCE:
#
# [14] PARA: Confidential, Portland,Oregon
#
# [15] PARA: Oracle PL/SQL Developer
#
# [16] PARA: Roles & Responsibilities:
#
# [17] LIST: 16 items
#       - Developed various PL/SQL objects like procedures, functions,...
#       - Involved in interacting with the end-user (client) to gather...
#
# [18] PARA: Environment: Oracle 11g/10g, SQL, PLSQL, Shell Scripting, Putty, JavaScript, Oracle SQL Developer, T...
#
# [19] PARA: Confidential, Dallas, TX
#
# [20] PARA: Oracle PL/SQL Developer.
#
# [21] PARA: Roles &Responsibilities:
#
# [22] LIST: 12 items
#       - Worked to Analyze, Design, Development, and testing of the a...
#       - Participate in development of the application by writing pro...
#
# [23] PARA: Environment: Oracle 12c/11g, TOAD, Oracle SQL Developer, Shell Scripts, Microsoft Visual Source Safe...
#
# [24] PARA: Confidential, Austin, TX
#
# [25] LIST: 15 items
#       - Developed PL/SQL Packages , Procedures, and Functions in acc...
#       - Involved as a key team member for Requirement Analysis durin...
#
# [26] PARA: Environment: Oracle 12c/11g, UNIX, Sybase 9.0, TOAD, JavaScript, Oracle SQL Developer, Oracle Forms ...
#
# [27] PARA: Confidential, Woonsocket, RI
#
# [28] LIST: 14 items
#       - Developed PL/SQL Procedures and Functions accordance with th...
#       - Created PL/SQL packages for calculation of metrics statistic...
#
# [29] PARA: Environment: Oracle 11g/10g, SQL*Loader, SQL, PLSQL, Putty, Shell Scripting, Informatica 9.0, Oracle...
#
# [30] PARA: Confidential
#
# [31] PARA: Oracle Developer
#
# [32] LIST: 12 items
#       - Created various SQL and PL/SQL scripts for verification of t...
#       - Created Custom Triggers, Stored Procedures, Packages, and SQ...
#
# [33] PARA: Environment: Oracle 10g, SQL, PL/SQL, Oracle Forms, Oracle Reports, Java, Putty, TOAD, XML, HTML, UN...
#
# Saved results to post_content_fixed.json
# Total structured blocks extracted: 34

# %%
def extract_post_body_safe(url,
                           target_class=None,
                           class_regex=None,
                           allow_fallback=True,
                           debug=False,
                           min_word_threshold=120):
    """
    Extracts structured content (<p>, <ul>, <li>, .media-body job roles)
    from the main post container, skipping oversized text blocks.
    """
    headers = {"User-Agent": "Mozilla/5.0 (X11; Linux x86_64)"}
    resp = requests.get(url, headers=headers, timeout=20)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    normalize_breaks(soup)

    # Identify container
    container = None
    if target_class:
        container = soup.find("div", class_=target_class)
    if not container and class_regex:
        container = soup.find("div", class_=re.compile(class_regex))
    if not container and allow_fallback:
        divs = soup.find_all("div")
        if divs:
            container = max(divs, key=lambda d: len(d.get_text(strip=True)))
    if not container:
        raise ValueError("Could not find a suitable container.")

    raw_container_text = container.get_text(separator="\n", strip=True)
    container_text = clean_whitespace(raw_container_text)

    structured_content = []
    skipped_blocks = []  # 🔹 Track skipped text blocks
    processed_elements = set()  # 🔹 Track already processed elements to avoid duplicates

    # 1️⃣ Handle .media-body blocks and their content
    for media in container.find_all("div", class_=re.compile(r"media-body")):
        role_data = {}
        
        # FIX: Look for h3 anywhere within media-body, not just direct children
        job_title_tag = media.find("h3")
        if not job_title_tag:
            # Also check for other potential job title tags
            job_title_tag = media.find(["h1", "h2", "h3", "h4"])
        
        if job_title_tag:
            role_data["job_role"] = clean_whitespace(job_title_tag.get_text())
            # Mark this element as processed
            processed_elements.add(job_title_tag)

        sub_blocks = []
        # Process direct children paragraphs and lists
        for child in media.find_all(["p", "ul"], recursive=False):
            processed_elements.add(child)
            
            if child.name == "p":
                text = clean_whitespace(" ".join(child.stripped_strings))
                # 🚫 Skip overly long text blocks
                if len(text.split()) > min_word_threshold:
                    skipped_blocks.append(text[:120] + "...")
                    continue
                if text:
                    sub_blocks.append({"type": "p", "text": text})
            elif child.name == "ul":
                items = []
                for li in child.find_all("li", recursive=False):
                    li_text = clean_whitespace(" ".join(li.stripped_strings))
                    # 🚫 Skip overly long list items
                    if len(li_text.split()) > min_word_threshold:
                        skipped_blocks.append(li_text[:120] + "...")
                        continue
                    if li_text:
                        items.append(li_text)
                if items:
                    sub_blocks.append({"type": "ul", "items": items})
        
        # Also process any paragraphs/lists that might be in nested divs but still part of this media-body
        for element in media.find_all(["p", "ul"]):
            if element in processed_elements:
                continue
                
            if element.name == "p":
                text = clean_whitespace(" ".join(element.stripped_strings))
                if len(text.split()) > min_word_threshold:
                    skipped_blocks.append(text[:120] + "...")
                    continue
                if text and element not in processed_elements:
                    sub_blocks.append({"type": "p", "text": text})
                    processed_elements.add(element)
            elif element.name == "ul":
                items = []
                for li in element.find_all("li", recursive=False):
                    li_text = clean_whitespace(" ".join(li.stripped_strings))
                    if len(li_text.split()) > min_word_threshold:
                        skipped_blocks.append(li_text[:120] + "...")
                        continue
                    if li_text:
                        items.append(li_text)
                if items and element not in processed_elements:
                    sub_blocks.append({"type": "ul", "items": items})
                    processed_elements.add(element)

        if sub_blocks or "job_role" in role_data:
            role_data["content"] = sub_blocks
            structured_content.append(role_data)

    # 2️⃣ Handle normal paragraphs and lists not under media-body and not already processed
    for element in container.find_all(["p", "ul"]):
        if element in processed_elements:
            continue
            
        # Skip if this element is inside any media-body (should already be processed)
        if element.find_parent("div", class_=re.compile(r"media-body")):
            continue

        if element.name == "p":
            text = clean_whitespace(" ".join(element.stripped_strings))
            # 🚫 Skip overly long text blocks
            if len(text.split()) > min_word_threshold:
                skipped_blocks.append(text[:120] + "...")
                continue
            if text:
                structured_content.append({"type": "p", "text": text})
                processed_elements.add(element)

        elif element.name == "ul":
            items = []
            for li in element.find_all("li", recursive=False):
                li_text = clean_whitespace(" ".join(li.stripped_strings))
                # 🚫 Skip overly long list items
                if len(li_text.split()) > min_word_threshold:
                    skipped_blocks.append(li_text[:120] + "...")
                    continue
                if li_text:
                    items.append(li_text)
            if items:
                structured_content.append({"type": "ul", "items": items})
                processed_elements.add(element)

    # Rest of your code remains the same...
    joined_p = "\n\n".join(
        [b["text"] for b in structured_content if b.get("type") == "p"]
    )

    container_words = len(container_text.split())
    joined_words = len(joined_p.split()) if joined_p else 0

    warnings = []
    missing_excerpt = ""
    if container_words > joined_words + 20:
        temp = container_text
        for block in structured_content:
            if block.get("type") == "p":
                temp = temp.replace(block["text"], "")
            elif block.get("type") == "ul":
                for item in block["items"]:
                    temp = temp.replace(item, "")
            elif "job_role" in block:
                temp = temp.replace(block["job_role"], "")
                for sub in block.get("content", []):
                    if sub.get("type") == "p":
                        temp = temp.replace(sub["text"], "")
                    elif sub.get("type") == "ul":
                        for item in sub["items"]:
                            temp = temp.replace(item, "")
        missing_excerpt = temp.strip()[:800]
        if missing_excerpt:
            warnings.append("Container has additional text not captured by structured tags.")

    if "<script" in resp.text.lower() and (container_words == 0 or joined_words == 0):
        warnings.append("Page might be JS-rendered.")

    if debug:
        print("===== DEBUG INFO =====")
        print("Container classes:", container.get("class"))
        print("Job roles found:", sum(1 for b in structured_content if "job_role" in b))
        print("Paragraphs:", sum(1 for b in structured_content if b.get("type") == "p"))
        print("Lists:", sum(1 for b in structured_content if b.get("type") == "ul"))
        print("Skipped blocks:", len(skipped_blocks))
        print("Warnings:", warnings)
        print("======================")

    return {
        "structured_content": structured_content,
        "full_text": joined_p,
        "container_text": container_text,
        "missing_excerpt": missing_excerpt,
        "skipped_blocks": skipped_blocks,
        "warnings": warnings
    }



url = "https://www.hireitpeople.com/resume-database/77-oracle-resumes/142742-oracle-pl-sql-developer-resume-portland-oregon"
# Example usage
result = extract_post_body_safe(
    url,
    class_regex=r"(single-post-body|post-content|entry-content|article-body)",
    debug=True
)
# Out:
# ===== DEBUG INFO =====
# Container classes: ['single-post-body']
# Job roles found: 0
# Paragraphs: 27
# Lists: 6
# Skipped blocks: 1
# Warnings: ['Container has additional text not captured by structured tags.']
# ======================

# %%
print(json.dumps(result, indent=4))
# Out:
# {
#     "structured_content": [
#         {
#             "type": "p",
#             "text": "SUMMARY:"
#         },
#         {
#             "type": "ul",
#             "items": [
#                 "8+ years of profound working experience in SQL, PL/SQL programming, System Analysis, Design, Development, and Support of Oracle Database \u2026 in Production, Staging, Development, and Testing Environments.",
#                 "Expertise in writing SQL queries, Views, Materialized views, PL/SQL procedures, functions, packages, triggers, cursors, collections, Ref cursor, cursor variables, System reference cursor , Dynamic SQL.",
#                 "Experience in developing External Tables, Joins, Indexes, and Sequences.",
#                 "Experience in query optimization, performance, and tuning (PL/SQL) using SQL Trace , Explain Plan, Indexing, Hints, Bulk Binds, Bulk Collect, Creation of global temporary tables and table partitioning.",
#                 "Experience in using several built - in database packages such as DBMS JOB, DBMS OUTPUT , UTL FILE , and DBMS SQL to name a few.",
#                 "Experience in all the phases of SDLC, including requirements gathering, system design, Development, Unit testing, Integration testing, implementation, and production support.",
#                 "Solid development skills in Oracle tools and technologies including Oracle Forms and Oracle Reports.",
#                 "Designed and developed various Oracle Forms and Reports for both Oracle Applications and Custom Development.",
#                 "Experience in Scripting using SQL, PL/SQL, UNIX Shell programs and providing production Support.",
#                 "Experience in Database design using Normalization and E/R Diagrams .",
#                 "Experience in configuration, development, and testing of AutoSys and other scripts.",
#                 "Experience in data loading from other databases and text files into Oracle database using SQL*Loader .",
#                 "Used Query tuning techniques for better performance and execution through suitable Indexes, primary-foreign key constraints.",
#                 "Experience in working with SQL Server Reporting Tools (SSRS) and SQL Server Integration (SSIS).",
#                 "Hands on experience in ETL process using different ETL tools and using PLSQL to populate the tables in OLTP and OLAP Data warehousing environment.",
#                 "Experience with XML packages, XML parsing and loading into Oracle.",
#                 "Experience in COBOL to analyze and modify Open Cobol modules.",
#                 "Expertise in using tools such as TOAD, Oracle SQL Developer , SQL*Plus .",
#                 "Experience in writing Technical design documents and developing Unit Test documents.",
#                 "Very good knowledge in C/C++ , Java Script , Core Java ."
#             ]
#         },
#         {
#             "type": "p",
#             "text": "TECHNICAL SKILLS:"
#         },
#         {
#             "type": "p",
#             "text": "Operating System: Windows 7/10, Linux, UNIX (Sun Solaris, HP-UX)."
#         },
#         {
#             "type": "p",
#             "text": "Oracle 12c/11g/10g/9i, MS: SQL Server."
#         },
#         {
#             "type": "p",
#             "text": "Web Technologies: HTML, DHTML, Java Script, XML."
#         },
#         {
#             "type": "p",
#             "text": "Languages: C, C++, SQL, PL/ SQL."
#         },
#         {
#             "type": "p",
#             "text": "Scripting Languages: UNIX Shell Scripting"
#         },
#         {
#             "type": "p",
#             "text": "Database Tools: SQL*PLUS, TOAD, SQL*Tool, PL/SQL Developer"
#         },
#         {
#             "type": "p",
#             "text": "MS: Office (Access, Word, Excel, PowerPoint)"
#         },
#         {
#             "type": "p",
#             "text": "Version Control: CVS, SVN, GITHUB"
#         },
#         {
#             "type": "p",
#             "text": "Agile Tools/Methodologies: Jira, RTC, SCRUM"
#         },
#         {
#             "type": "p",
#             "text": "PROFESSIONAL EXPERIENCE:"
#         },
#         {
#             "type": "p",
#             "text": "Confidential, Portland,Oregon"
#         },
#         {
#             "type": "p",
#             "text": "Oracle PL/SQL Developer"
#         },
#         {
#             "type": "p",
#             "text": "Roles & Responsibilities:"
#         },
#         {
#             "type": "ul",
#             "items": [
#                 "Developed various PL/SQL objects like procedures, functions, packages, and triggers in accordance with the business needs.",
#                 "Involved in interacting with the end-user (client) to gather business requirements and modeling the business requirements.",
#                 "Participated in analyzing the requirements for the logical and physical design of the database.",
#                 "Involved in tuning and query optimizing SQL queries by using quest control tools and manual by EXPLAIN PLAN .",
#                 "PL/SQL Collections were extensively used for high performance of stored procedures.",
#                 "Collaborate with the DBA and Development Team in successful implementation of data warehouse release.",
#                 "Populating the data warehouse tables using SQL*Loader .",
#                 "Implemented complex views, procedures, functions, packages, and triggers in PL/SQL.",
#                 "Performed exception handling for data that did not conform to the required format.",
#                 "Responsible for making the merged data in turn available to other clients.",
#                 "Implemented PL/SQL scripts in accordance with the necessary Business rules and procedures.",
#                 "Applications database pool monitoring and thread monitoring in the JVM .",
#                 "Developed PL/SQL packages and procedures for the back-end processing of the proposed data base design.",
#                 "Created JavaScript to create end-user application, conduct testing and training, design user interface.",
#                 "Coded PL/SQL Procedures, Functions, and Packages for batch processing of the applications.",
#                 "Conducted PL/SQL training session for co-workers to educate about the latest PL/SQL features, PL/SQL performance tuning."
#             ]
#         },
#         {
#             "type": "p",
#             "text": "Environment: Oracle 11g/10g, SQL, PLSQL, Shell Scripting, Putty, JavaScript, Oracle SQL Developer, Toad, AutoSys, UNIX, Notepad++."
#         },
#         {
#             "type": "p",
#             "text": "Confidential, Dallas, TX"
#         },
#         {
#             "type": "p",
#             "text": "Oracle PL/SQL Developer."
#         },
#         {
#             "type": "p",
#             "text": "Roles &Responsibilities:"
#         },
#         {
#             "type": "ul",
#             "items": [
#                 "Worked to Analyze, Design, Development, and testing of the application.",
#                 "Participate in development of the application by writing procedures, Functions, Triggers, Cursors, Complex SQL queries etc.",
#                 "Developed, Analyzing, and writing PL/SQL scripts. Ability to use advanced features such as ref cursors and built in package/complex SQL statements using multi table joins, exist clauses and ability to tune SQL.",
#                 "Worked on the scripts for Open COBOL modules according to the business requirement.",
#                 "Developed Test plans and Unit Testing , System Integration Testing through Production implementation",
#                 "Developed Oracle Forms and Reports as per client requirements and making them web enabled using Oracle Reports builder 11g/12c and Oracle Forms builder 11g/12c respectively in Web logic environment.",
#                 "Developed reports using complex queries as per business user request as a part of production support.",
#                 "Created and modified several UNIX Shell Scripts according to the changing needs of the project and client requirements.",
#                 "Developed Unix Shell Scripts to process the files on daily basis like renaming the file, extracting date from the file, unzipping the file and remove the junk characters from the file before loading them into the base tables.",
#                 "Interacted with requirements team for new business requirements or enhancements or change requests to implement in the application.",
#                 "Created high quality and well documented code according to standards.",
#                 "Involved in daily status calls and meetings through Agile."
#             ]
#         },
#         {
#             "type": "p",
#             "text": "Environment: Oracle 12c/11g, TOAD, Oracle SQL Developer, Shell Scripts, Microsoft Visual Source Safe, Core FTP LE, PUTTY, Open Cobol, Forms Builder, Forms API Master, Oracle Forms 11g/12c, Oracle Reports 11g/12c."
#         },
#         {
#             "type": "p",
#             "text": "Confidential, Austin, TX"
#         },
#         {
#             "type": "ul",
#             "items": [
#                 "Developed PL/SQL Packages , Procedures, and Functions in accordance with the business requirements for extracting legacy data and loading data into database tables as part of data migration.",
#                 "Involved as a key team member for Requirement Analysis during the design phase and developed various Design documents according to the user requirements.",
#                 "Involved in Code Reviews and preparing Unit test cases.",
#                 "Used Quest code tester for Oracle, a component of Toad used to identify and eliminate the costly bugs and functional errors and used right data model for the data mart based on the requirements.",
#                 "Created technical mapping documents as part of data modeling and design.",
#                 "Created data stores, interfaces, procedures, packages, and scenarios in ODI repositories.",
#                 "Designed and generated Oracle Forms and Oracle Reports .",
#                 "Developed UNIX Shell scripts to automate repetitive database processes.",
#                 "Generated dynamic web-reports using HTML, JavaScript.",
#                 "Efficiently designed the Database schema suitable for the client requirements. Implemented the Client-side HTML/ java script based Pages for User Interaction with the system.",
#                 "Coded several Unix Scripts to interface with several external databases, Sybase ASE and SQL Server and packaged applications. customers in troubleshooting issues with their applications in AutoSys .",
#                 "Physical Data Warehouse design, table partitioning, indexing strategy , materialized views, hands on with PL/ SQL, SQL development using packages and program units.",
#                 "Developed PL/SQL functions to facilitate business functions and calculations and did required modifications to the existing once.",
#                 "Created complex stored procedures, views, SQL joins and scripts .",
#                 "Create and edit SSIS packages including error management and logging."
#             ]
#         },
#         {
#             "type": "p",
#             "text": "Environment: Oracle 12c/11g, UNIX, Sybase 9.0, TOAD, JavaScript, Oracle SQL Developer, Oracle Forms 11g, Oracle Reports 11g, Putty, Shell Scripts, AutoSys"
#         },
#         {
#             "type": "p",
#             "text": "Confidential, Woonsocket, RI"
#         },
#         {
#             "type": "ul",
#             "items": [
#                 "Developed PL/SQL Procedures and Functions accordance with the business requirements for loading data into database tables.",
#                 "Created PL/SQL packages for calculation of metrics statistics across 13 states by including state and domain wise parameters which resulted in reducing the report generation time by almost 90%.",
#                 "Developed the SQL code for performance and penalty statistics calculation.",
#                 "Analyzed and framed the business logic for the ETL process as per the requirements.",
#                 "Created ETL Processes using Informatica Version 9.0 .",
#                 "Executing Daily and Monthly reports in UNIX and automated the scripts using shell script.",
#                 "Created SQL Loader scripts to load data into temporary staging tables.",
#                 "Created scripts for Views, Materialized Views and Partitioned tables.",
#                 "Responsible for Analyzing and Implementing the Change Requests",
#                 "Monitoring day-to-day Process for different Data Loads and resolving Issues.",
#                 "Created complex stored procedures, views, SQL joins and scripts.",
#                 "Writing high quality and well documented code according to standards.",
#                 "Involved in fine tuning stored procedures by making use of PL/SQL Collections and its BULK FETCH and BULK INSERT features.",
#                 "Involved in daily status calls with clients."
#             ]
#         },
#         {
#             "type": "p",
#             "text": "Environment: Oracle 11g/10g, SQL*Loader, SQL, PLSQL, Putty, Shell Scripting, Informatica 9.0, Oracle SQL Developer, TOAD."
#         },
#         {
#             "type": "p",
#             "text": "Confidential"
#         },
#         {
#             "type": "p",
#             "text": "Oracle Developer"
#         },
#         {
#             "type": "ul",
#             "items": [
#                 "Created various SQL and PL/SQL scripts for verification of the required functionalities.",
#                 "Created Custom Triggers, Stored Procedures, Packages, and SQL Scripts .",
#                 "Created numerous web based Forms and Reports.",
#                 "Loaded traffic data logs into staging tables using SQL loader and shell scripts.",
#                 "Developed Forms, Packages, Triggers , and Shell Scripts to load the staging table data into Traffic Mart System .",
#                 "Writing scripts to create partitions, exchange partitions, analyze for performance tuning.",
#                 "Developed packages, functions, procedures, database triggers as part of the ETL process.",
#                 "Used UTL FILE (file handler), DBMS JOB, DBMS ALERT and other utility built-in Packages in PL/SQL.",
#                 "Worked on complete SDLC (System Development Life Cycle) including system analysis, high level design, detailed design, developing, coding, and testing.",
#                 "Creation of database objects like tables, views, procedures, packages using SQL* Plus and PL/SQL .",
#                 "Performed Data validations and mappings at staging table level.",
#                 "Created Complex Dynamic / Static / Parameterized Reports and Charts using Report 6i."
#             ]
#         },
#         {
#             "type": "p",
#             "text": "Environment: Oracle 10g, SQL, PL/SQL, Oracle Forms, Oracle Reports, Java, Putty, TOAD, XML, HTML, UNIX, SQL*Loader."
#         }
#     ],
#     "full_text": "SUMMARY:\n\nTECHNICAL SKILLS:\n\nOperating System: Windows 7/10, Linux, UNIX (Sun Solaris, HP-UX).\n\nOracle 12c/11g/10g/9i, MS: SQL Server.\n\nWeb Technologies: HTML, DHTML, Java Script, XML.\n\nLanguages: C, C++, SQL, PL/ SQL.\n\nScripting Languages: UNIX Shell Scripting\n\nDatabase Tools: SQL*PLUS, TOAD, SQL*Tool, PL/SQL Developer\n\nMS: Office (Access, Word, Excel, PowerPoint)\n\nVersion Control: CVS, SVN, GITHUB\n\nAgile Tools/Methodologies: Jira, RTC, SCRUM\n\nPROFESSIONAL EXPERIENCE:\n\nConfidential, Portland,Oregon\n\nOracle PL/SQL Developer\n\nRoles & Responsibilities:\n\nEnvironment: Oracle 11g/10g, SQL, PLSQL, Shell Scripting, Putty, JavaScript, Oracle SQL Developer, Toad, AutoSys, UNIX, Notepad++.\n\nConfidential, Dallas, TX\n\nOracle PL/SQL Developer.\n\nRoles &Responsibilities:\n\nEnvironment: Oracle 12c/11g, TOAD, Oracle SQL Developer, Shell Scripts, Microsoft Visual Source Safe, Core FTP LE, PUTTY, Open Cobol, Forms Builder, Forms API Master, Oracle Forms 11g/12c, Oracle Reports 11g/12c.\n\nConfidential, Austin, TX\n\nEnvironment: Oracle 12c/11g, UNIX, Sybase 9.0, TOAD, JavaScript, Oracle SQL Developer, Oracle Forms 11g, Oracle Reports 11g, Putty, Shell Scripts, AutoSys\n\nConfidential, Woonsocket, RI\n\nEnvironment: Oracle 11g/10g, SQL*Loader, SQL, PLSQL, Putty, Shell Scripting, Informatica 9.0, Oracle SQL Developer, TOAD.\n\nConfidential\n\nOracle Developer\n\nEnvironment: Oracle 10g, SQL, PL/SQL, Oracle Forms, Oracle Reports, Java, Putty, TOAD, XML, HTML, UNIX, SQL*Loader.",
#     "container_text": "SUMMARY:\n8+ years of profound working experience in SQL, PL/SQL programming, System Analysis, Design, Development, and Support of\nOracle Database \u2026\nin Production, Staging, Development, and Testing Environments.\nExpertise in writing SQL queries, Views, Materialized views, PL/SQL procedures, functions, packages, triggers, cursors, collections, Ref cursor, cursor variables,\nSystem reference cursor\n,\nDynamic SQL.\nExperience in developing External Tables, Joins, Indexes, and Sequences.\nExperience in query optimization, performance, and tuning (PL/SQL) using\nSQL Trace\n, Explain Plan, Indexing, Hints, Bulk Binds, Bulk Collect, Creation of global temporary tables and table partitioning.\nExperience in using several built - in database packages such as\nDBMS JOB, DBMS OUTPUT\n,\nUTL FILE\n, and\nDBMS SQL\nto name a few.\nExperience in all the phases of SDLC, including requirements gathering, system design, Development, Unit testing, Integration testing, implementation, and production support.\nSolid development skills in Oracle tools and technologies including Oracle Forms and Oracle Reports.\nDesigned and developed various Oracle Forms and Reports for both Oracle Applications and Custom Development.\nExperience in Scripting using\nSQL, PL/SQL, UNIX\nShell programs and providing production Support.\nExperience in Database design using Normalization and\nE/R Diagrams\n.\nExperience in configuration, development, and testing of\nAutoSys\nand other scripts.\nExperience in data loading from other databases and text files into Oracle database using\nSQL*Loader\n.\nUsed Query tuning techniques for better performance and execution through suitable Indexes, primary-foreign key constraints.\nExperience in working with\nSQL Server Reporting Tools\n(SSRS) and\nSQL Server Integration\n(SSIS).\nHands on experience in ETL process using different ETL tools and using PLSQL to populate the tables in\nOLTP\nand\nOLAP\nData warehousing environment.\nExperience with XML packages,\nXML\nparsing and loading into Oracle.\nExperience in\nCOBOL\nto analyze and modify Open Cobol modules.\nExpertise in using tools such as\nTOAD,\nOracle SQL Developer\n, SQL*Plus\n.\nExperience in writing Technical design documents and developing Unit Test documents.\nVery good knowledge in\nC/C++\n,\nJava Script\n,\nCore Java\n.\nTECHNICAL SKILLS:\nOperating System:\nWindows 7/10, Linux, UNIX (Sun Solaris, HP-UX).\nOracle 12c/11g/10g/9i, MS:\nSQL Server.\nWeb Technologies:\nHTML, DHTML, Java Script, XML.\nLanguages:\nC, C++, SQL, PL/ SQL.\nScripting Languages:\nUNIX Shell Scripting\nDatabase Tools:\nSQL*PLUS, TOAD, SQL*Tool, PL/SQL Developer\nMS:\nOffice (Access, Word, Excel, PowerPoint)\nVersion Control:\nCVS, SVN, GITHUB\nAgile Tools/Methodologies:\nJira, RTC, SCRUM\nPROFESSIONAL EXPERIENCE:\nConfidential, Portland,Oregon\nOracle PL/SQL Developer\nRoles & Responsibilities:\nDeveloped various PL/SQL objects like procedures, functions, packages, and triggers in accordance with the business needs.\nInvolved in interacting with the end-user (client) to gather business requirements and modeling the business requirements.\nParticipated in analyzing the requirements for the logical and physical design of the database.\nInvolved in tuning and query optimizing SQL queries by using quest control tools and manual by\nEXPLAIN PLAN\n.\nPL/SQL Collections were extensively used for high performance of stored procedures.\nCollaborate with the\nDBA\nand Development Team in successful implementation of data warehouse release.\nPopulating the data warehouse tables using\nSQL*Loader\n.\nImplemented complex views, procedures, functions, packages, and triggers in PL/SQL.\nPerformed exception handling for data that did not conform to the required format.\nResponsible for making the merged data in turn available to other clients.\nImplemented PL/SQL scripts in accordance with the necessary Business rules and procedures.\nApplications database pool monitoring and ...
#     "missing_excerpt": "8+ years of profound working experience in SQL, PL/SQL programming, System Analysis, Design, Development, and Support of\nOracle Database \u2026\nin Production, Staging, Development, and Testing Environments.\nExpertise in writing SQL queries, Views, Materialized views, PL/SQL procedures, functions, packages, triggers, cursors, collections, Ref cursor, cursor variables,\nSystem reference cursor\n,\nDynamic SQL.\n\nExperience in query optimization, performance, and tuning (PL/SQL) using\nSQL Trace\n, Explain Plan, Indexing, Hints, Bulk Binds, Bulk Collect, Creation of global temporary tables and table partitioning.\nExperience in using several built - in database packages such as\nDBMS JOB, DBMS OUTPUT\n,\nUTL FILE\n, and\nDBMS SQL\nto name a few.\n\n\n\nExperience in Scripting using\nSQL, PL/SQL, UNIX\nShell programs",
#     "skipped_blocks": [
#         "SUMMARY: 8+ years of profound working experience in SQL, PL/SQL programming, System Analysis, Design, Development, and S..."
#     ],
#     "warnings": [
#         "Container has additional text not captured by structured tags."
#     ]
# }

# %%
r = result['structured_content']
content = r.get("content", [])
content
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 2
#       1 r = result['structured_content']
# ----> 2 content = r.get("content", [])
#       3 content
#
# AttributeError: 'list' object has no attribute 'get'

# %%
content = result.get("content", result.get("structured_content", []))

# %%
from typing import List, Optional
from pydantic import BaseModel
import json

class Experience(BaseModel):
    job_role: str
    responsibilities: List[str]
    environment: Optional[str] = None

class Resume(BaseModel):
    professional_summary: List[str]
    technical_skills: List[str]
    experiences: List[Experience]


def parse_resume_json(input_path: str, output_path: str) -> None:
    """
    Parse and merge a raw JSON resume (with text and tags)
    into a structured Resume model.
    """

    # Load JSON
    with open(input_path, "r") as f:
        data = json.load(f)

    # If JSON has outer key
    content = data.get("content", data.get("structured_content", []))

    # Buffers
    professional_summary, technical_skills = [], []
    experiences = []

    current_section = None
    current_exp = None

    for block in content:
        text = block.get("text", "").strip()
        tag = block.get("type", "").lower()

        if not text:
            continue

        lower_text = text.lower()

        # --- Identify section headers ---
        if "summary" in lower_text:
            current_section = "summary"
            continue
        elif "technical skills" in lower_text:
            current_section = "technical"
            continue
        elif "professional experience" in lower_text or "experience" in lower_text:
            current_section = "experience"
            continue

        # --- Handle sections ---
        if current_section == "summary":
            professional_summary.append(text)

        elif current_section == "technical":
            technical_skills.append(text)

        elif current_section == "experience":
            # Detect start of new experience
            if lower_text.startswith("confidential"):
                # Save previous one
                if current_exp:
                    experiences.append(current_exp)
                current_exp = Experience(job_role="", responsibilities=[], environment=None)

            # Detect job role (next P tag after confidential)
            elif tag == "p" and current_exp and not current_exp.job_role:
                current_exp.job_role = text

            # UL → responsibilities
            elif tag == "ul" and current_exp:
                current_exp.responsibilities.append(text)

            # Detect environment line
            elif "environment" in lower_text and current_exp:
                current_exp.environment = text

    # Append the last experience
    if current_exp:
        experiences.append(current_exp)

    # --- Build and validate structured resume ---
    resume = Resume(
        professional_summary=professional_summary,
        technical_skills=technical_skills,
        experiences=experiences,
    )

    # Save structured output
    with open(output_path, "w") as f:
        json.dump(resume.dict(), f, indent=4)

    print(f"✅ Resume successfully parsed and saved to {output_path}")

# %%
import json

def split_sections(input_json_path, output_json_path):
    with open(input_json_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    structured_content = data.get("structured_content", [])
    result = {}
    current_section = None
    buffer = []

    def flush_section():
        """Helper to flush current buffer into result dict."""
        nonlocal current_section, buffer
        if current_section:
            # Merge text + lists in a readable way
            merged_text = []
            for item in buffer:
                if item["type"] == "p" and "text" in item:
                    merged_text.append(item["text"].strip())
                elif item["type"] == "ul" and "items" in item:
                    merged_text.extend([f"- {i.strip()}" for i in item["items"]])
            result[current_section] = "\n".join(merged_text).strip()
        buffer = []

    # Loop through each block
    for block in structured_content:
        if block["type"] == "p":
            text = block["text"].strip().rstrip(":")
            # Section heading candidates (uppercase)
            if text.isupper() and len(text.split()) <= 3:
                # Flush previous section content
                flush_section()
                # Start new section
                current_section = text
            else:
                buffer.append(block)
        else:
            buffer.append(block)

    # Flush last section
    flush_section()

    with open(output_json_path, 'w', encoding='utf-8') as f:
        json.dump(result, f, indent=4, ensure_ascii=False)

    print(f"✅ Output JSON saved to: {output_json_path}")
    return result

# %%
split_sections("post_content_79_2.json", "structured_resume.json")
# Out:
# ✅ Output JSON saved to: structured_resume.json
# {'SUMMARY': '- Over 18 years of experience in Application design, development and data architecture on a wide variety of platforms, operating systems and databases mainly in Banking and Finance domain.\n- Extensive experience managing and supporting multiple projects involving design and development of OLTP & Data warehouse databases in Oracle 12c/11.2/10g , Teradata, Netezza, NoSQL databases - Cassandra , SQL Server across multiple industries such as Banking, Insurance, Financial, Taxation.\n- More than 8 years of experience as D ata architect involved in design and implementation of database solutions, data integration techniques, D ata modeling , Master Data management & data governance, data quality/data profiling techniques\n- Extensive experience in Oracle Sql & PLSQL code development, writing and reviewing procedures, functions, packages , managing indexes and partitions , reviewing execution plans for query tuning and optimization, OEM database monitoring, OBIEE repositories and dashboards\n- Experience handling high volume data load using SQL*Loade r, external tables, exchange partition, Oracle Data Pump, Implemented data compression in Oracle Exadata to reduce storage and improve performance for certain queries in Oracle Exadata\n- Providing technical guidance to project teams in all phases of SLDC, creating test cases and providing support during testing and implementation, UI integration and production releases\n- Experience in handling ETL tools like Informatica, Datastage, Unix shells scripting\n- Familiar with Hadoop information architecture, NoSql Database - Caasandra\n- As Technical lead supervising progress of development and testing activities using Agile methodology, daily status call, tracking project deliverables\n- Excellent communication and interpersonal skills.',
#  'TECHNICAL SKILLS': 'RDBMS: ORACLE 12.2/11.2/10 g/9i, Teradata, Netezza, SQL Server, Access, Hadoop ecosystem Hive, MapReduce, NoSQL DB- Cassandra\nTools: SQL, PLSQL, Oracle Enterprise Manager, OBIEE 11g, SQL* Loader, DataPump, Export and Import Utilities, Erwin, TOAD, Rational Clearcase, ClearQuest, Business Object, Cognos\nScripting Languages: Python, SQL, PL/SQL, SQL*Plus, Unix Shell Scripting\nETL Tools: Informatica-Power Center 9.6, Datastage\nVersion Control Tools: Cleacase, clearquest, SVN, Jira',
#  'PROFESSIONAL EXPERIENCE': 'Confidential, NY\nSr. Oracle Developer /Data Architect\n- Involved in design and implementation of data warehouse environment including database architecture, metadata, and repository creation, technical specifications, Logical and physical data modeling, dimensional modeling, star schema , fact and dimensions\n- Design and development of reporting database, source system analysis and mapping entities from source to target, loading data from various source system onto an ETL layer and then cleansed, scrubbed for anomalies, business transformation logic applied and transformed data is then loaded onto staging layer in the Database.\n- Responsible for designing database structures, Oracle 11.2 SQL and PLSQL code development writing and restructuring packages, procedures & functions, using collections, analytical functions, implementing data masking to establish business rules\n- Reviewing and restructuring sql queries & PLSQL code, join strategies, indexes & table partitions, reviewing explain plan, hints, query execution plans, AWR reports, parallel loading techniques using staging tables, implementing data compression on large tables\n- Interacting with architect and support team for design and development of solutions using technologies like Hadoop, MapReduce, Cassandra etc.\n- Troubleshoot database issues in UAT and production environments\nEnvironment: Oracle 12/11.2, NoSQL DB-Cassandra, MapReduce, Toad, SQL Navigator, Erwin, MS Visual Studio, Relational ClearQuest, Clearcase, MS-Visio, Unix shell scripting, Data Pump, Autosys\nConfidential, Hoboken, NJ\nSr. Oracle Developer\n- Involved in various phases of development lifecycle, requirements gathering, understanding business processes, source system analysis, creating logical and physical Data models, defining data quality and data profiling techniques, creating Source file layout mapping specifications & metadata repository\n- As a Database Technical Lead, responsible for designing database structures, Oracle 11.2 SQL and PLSQL code development, writing packages, procedures/functions and triggers, analytical functions, managing join strategies, performance indexes & table partitions, data masking using data redaction\n- Responsible for Sql query optimization & PLSQL code tuning using Explain Plan, gathering statistics, monitoring database performance using OEM, AWR reports\n- Experience in defining high volume data load using exchange partition technique, loading data from various source file formats (csv, xml, txt, excel, unstructured data) using external tables, Sql*Loader, Utl file, utilities like export import and Data Pump, scheduling jobs,\n- Creating OBIEE RPDs for the data structures, designing dashboards and reporting queries, configuring reporting schedules for business users\n- Providing support for ETL processes, test plans and integration testing, production support (24/7) for resolving critical data issues managing, mentoring development team\n- Monitoring progress of development and testing activities using Agile methodology, daily status call, tracking project deliverables\nEnvironment: Oracle 12.2/11.2, Informatica 9.6,, Toad, SQL Navigator, OBIEE 11g, Erwin, MS Visual Studio, MS-Visio, Unix shell scripting, Data Pump, Autosys\nConfidential, Warren, NJ\nOracle Developer-DBA\n- Involved in gathering business requirements, liaising with Finance, Risk, Technology and FRO teams across the organizations, developing the end-to-end data warehouse solution architecture and documenting the technical specifications, build and manage Logical and Physical Data Model, designing extraction and loading techniques from various source systems like Oracle, Netezza, Teradata, Sybase\n- Defined and documented source to target mappings, attributes, data types, cardinality, data quality standards for banking products namely -Deposits, Mortgages, Securities, Loans, Derivatives for both wholesale and Retail.\n- Responsible for Oracle 10g/11g Sql & PL ...

# %%
content
# Out:
# []

# %%
ls
# Out:
# data_scraping.ipynb     post_content_79_2.json  scraping_utils.py
# output.json             resume.json             scraping_v2.ipynb
# post_content.json       resume.txt              test.ipynb
# post_content_79.json    scraping.ipynb          test.py

# %%
import json
from typing import Dict, List, Any

def parse_resume_json(input_json_file: str, output_json_file: str) -> None:
    """
    Parse a resume JSON file and extract structured information based on the specified logic.
    
    Args:
        input_json_file: Path to the input JSON file
        output_json_file: Path to the output JSON file
    """
    
    # Load the input JSON file
    with open(input_json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
        data = data['structured_content']
    
    # Initialize the result structure
    result = {
        "summary": "",
        "technical_skills": "",
        "professional_experience": []
    }
    
    # Extract content (assuming the JSON has a structure with text content)
    # Adjust this based on your actual JSON structure
    content = data.get('content', []) or data.get('text', []) or data.get('elements', [])
    
    # Phase 1: Extract Summary (from summary to technical skills)
    summary_parts = []
    technical_skills_parts = []
    professional_summary_parts = []
    experiences = []
    current_experience = None
    
    in_summary = False
    in_technical_skills = False
    in_professional_summary = False
    in_experience = False
    found_technical_skills = False
    found_professional_summary = False
    
    for element in content:
        # Check if element is a dictionary with text/tag information
        if isinstance(element, dict):
            text = element.get('text', '').lower().strip()
            tag = element.get('tag', '').lower()
            
            # Start summary when we find "summary"
            if "summary" in text and not found_technical_skills:
                in_summary = True
                in_technical_skills = False
                in_professional_summary = False
                in_experience = False
                continue
            
            # Start technical skills when we find "technical skills"
            if "technical skills" in text:
                in_summary = False
                in_technical_skills = True
                in_professional_summary = False
                in_experience = False
                found_technical_skills = True
                continue
            
            # Start professional summary when we find "professional summary"
            if "professional summary" in text or "professional experience" in text:
                in_summary = False
                in_technical_skills = False
                in_professional_summary = True
                in_experience = False
                found_professional_summary = True
                continue
            
            # Start new experience when we find "confidential"
            if "confidential" in text and tag == 'p':
                # Save previous experience if exists
                if current_experience:
                    experiences.append(current_experience)
                
                # Start new experience
                current_experience = {
                    "job_role": "",
                    "responsibilities": []
                }
                in_summary = False
                in_technical_skills = False
                in_professional_summary = False
                in_experience = True
                continue
            
            # Extract job role (next P tag after confidential)
            if in_experience and tag == 'p' and not current_experience.get("job_role"):
                if "confidential" not in text:  # Skip the confidential tag itself
                    current_experience["job_role"] = element.get('text', '').strip()
                continue
            
            # Extract responsibilities (UL tags within experience)
            if in_experience and tag == 'ul':
                # Extract list items from UL
                list_items = element.get('items', [])
                for item in list_items:
                    if isinstance(item, str):
                        current_experience["responsibilities"].append(item.strip())
                    elif isinstance(item, dict):
                        current_experience["responsibilities"].append(item.get('text', '').strip())
                continue
            
            # Collect content based on current section
            if in_summary:
                summary_parts.append(element.get('text', '').strip())
            elif in_technical_skills:
                technical_skills_parts.append(element.get('text', '').strip())
            elif in_professional_summary and not in_experience:
                professional_summary_parts.append(element.get('text', '').strip())
        
        # Handle string elements directly
        elif isinstance(element, str):
            text = element.lower().strip()
            
            if "summary" in text and not found_technical_skills:
                in_summary = True
                in_technical_skills = False
                in_professional_summary = False
                in_experience = False
            elif "technical skills" in text:
                in_summary = False
                in_technical_skills = True
                in_professional_summary = False
                in_experience = False
                found_technical_skills = True
            elif "professional summary" in text or "professional experience" in text:
                in_summary = False
                in_technical_skills = False
                in_professional_summary = True
                in_experience = False
                found_professional_summary = True
            elif "confidential" in text:
                if current_experience:
                    experiences.append(current_experience)
                current_experience = {"job_role": "", "responsibilities": []}
                in_experience = True
            else:
                if in_summary:
                    summary_parts.append(element.strip())
                elif in_technical_skills:
                    technical_skills_parts.append(element.strip())
                elif in_professional_summary and not in_experience:
                    professional_summary_parts.append(element.strip())
    
    # Add the last experience if exists
    if current_experience:
        experiences.append(current_experience)
    
    # Build the result
    result["summary"] = " ".join(summary_parts).strip()
    result["technical_skills"] = " ".join(technical_skills_parts).strip()
    
    # If no technical skills found, use professional summary as fallback
    if not result["technical_skills"] and professional_summary_parts:
        result["technical_skills"] = " ".join(professional_summary_parts).strip()
    
    result["professional_experience"] = experiences
    
    # Save the result to output JSON file
    with open(output_json_file, 'w', encoding='utf-8') as f:
        json.dump(result, f, indent=2, ensure_ascii=False)

# Alternative version with more flexible element parsing
def parse_resume_json_advanced(input_json_file: str, output_json_file: str) -> None:
    """
    Advanced parser with more flexible element handling.
    """
    
    with open(input_json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    result = {
        "summary": "",
        "technical_skills": "",
        "professional_experience": []
    }
    
    content = data.get('content', []) or data.get('text', []) or data.get('elements', []) or []
    
    def extract_text(element):
        """Extract text from various element formats"""
        if isinstance(element, str):
            return element
        elif isinstance(element, dict):
            return element.get('text', '') or element.get('content', '') or ''
        return ''
    
    sections = {
        'summary': [],
        'technical_skills': [],
        'professional_experience': []
    }
    
    current_section = None
    current_experience = None
    
    for element in content:
        text = extract_text(element).lower().strip()
        original_text = extract_text(element).strip()
        
        # Determine current section
        if "summary" in text and current_section != 'technical_skills':
            current_section = 'summary'
        elif "technical skills" in text:
            current_section = 'technical_skills'
        elif "professional summary" in text or "professional experience" in text:
            current_section = 'professional_experience'
        elif "confidential" in text:
            # Start new experience
            if current_experience and current_experience.get('job_role') or current_experience.get('responsibilities'):
                sections['professional_experience'].append(current_experience)
            current_experience = {'job_role': '', 'responsibilities': []}
        
        # Collect content based on section
        if current_section and original_text:
            if current_section == 'professional_experience' and current_experience is not None:
                # Handle job role and responsibilities
                if not current_experience['job_role'] and "confidential" not in text:
                    current_experience['job_role'] = original_text
                elif isinstance(element, dict) and element.get('tag', '').lower() == 'ul':
                    # Extract list items
                    items = element.get('items', [])
                    for item in items:
                        item_text = extract_text(item)
                        if item_text:
                            current_experience['responsibilities'].append(item_text)
            else:
                # For summary and technical skills
                if current_section in sections and "confidential" not in text:
                    sections[current_section].append(original_text)
    
    # Add the last experience
    if current_experience and (current_experience.get('job_role') or current_experience.get('responsibilities')):
        sections['professional_experience'].append(current_experience)
    
    # Build final result
    result["summary"] = " ".join(sections['summary']).strip()
    result["technical_skills"] = " ".join(sections['technical_skills']).strip()
    result["professional_experience"] = sections['professional_experience']
    
    with open(output_json_file, 'w', encoding='utf-8') as f:
        json.dump(result, f, indent=2, ensure_ascii=False)

# %%
all_resume_links[0]
# Out:
# 'https://www.hireitpeople.com/resume-database/70-oracle-developers-resumes/628272-teradata-dba-resume-hoffman-estates-il-2'

# %%
parse_resume_json('post_content_79_2.json', 'output.json')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 parse_resume_json('post_content_79_2.json', 'output.json')
#
# Cell In[34], line 27, in parse_resume_json(input_json_file, output_json_file)
#      19 result = {
#      20     "summary": "",
#      21     "technical_skills": "",
#      22     "professional_experience": []
#      23 }
#      25 # Extract content (assuming the JSON has a structure with text content)
#      26 # Adjust this based on your actual JSON structure
# ---> 27 content = data.get('content', []) or data.get('text', []) or data.get('elements', [])
#      29 # Phase 1: Extract Summary (from summary to technical skills)
#      30 summary_parts = []
#
# AttributeError: 'list' object has no attribute 'get'

# %%
def naveen_parser(input_json_file: str, output_json_file: str) -> None:
    new_data = {}
    with open(input_json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    flag = None
    list_data = []
    data = data['structured_content']
    for block in data:
        if block.get("type") == "p":
            if(block.get("text").lower().strip() == "summary"):
                flag = "summary"
                new_data["summary"] = block.get("text")
        elif block.get("type") == "ul" and flag != None:

# %%
naveen_parser("post_content_79_2.json", "structured_resume.json")
# Out:
# SUMMARY:
# ['Over 18 years of experience in Application design, development and data architecture on a wide variety of platforms, operating systems and databases mainly in Banking and Finance domain.', 'Extensive experience managing and supporting multiple projects involving design and development of OLTP & Data warehouse databases in Oracle 12c/11.2/10g , Teradata, Netezza, NoSQL databases - Cassandra , SQL Server across multiple industries such as Banking, Insurance, Financial, Taxation.', 'More than 8 years of experience as D ata architect involved in design and implementation of database solutions, data integration techniques, D ata modeling , Master Data management & data governance, data quality/data profiling techniques', 'Extensive experience in Oracle Sql & PLSQL code development, writing and reviewing procedures, functions, packages , managing indexes and partitions , reviewing execution plans for query tuning and optimization, OEM database monitoring, OBIEE repositories and dashboards', 'Experience handling high volume data load using SQL*Loade r, external tables, exchange partition, Oracle Data Pump, Implemented data compression in Oracle Exadata to reduce storage and improve performance for certain queries in Oracle Exadata', 'Providing technical guidance to project teams in all phases of SLDC, creating test cases and providing support during testing and implementation, UI integration and production releases', 'Experience in handling ETL tools like Informatica, Datastage, Unix shells scripting', 'Familiar with Hadoop information architecture, NoSql Database - Caasandra', 'As Technical lead supervising progress of development and testing activities using Agile methodology, daily status call, tracking project deliverables', 'Excellent communication and interpersonal skills.']
# TECHNICAL SKILLS:
# RDBMS: ORACLE 12.2/11.2/10 g/9i, Teradata, Netezza, SQL Server, Access, Hadoop ecosystem Hive, MapReduce, NoSQL DB- Cassandra
# Tools: SQL, PLSQL, Oracle Enterprise Manager, OBIEE 11g, SQL* Loader, DataPump, Export and Import Utilities, Erwin, TOAD, Rational Clearcase, ClearQuest, Business Object, Cognos
# Scripting Languages: Python, SQL, PL/SQL, SQL*Plus, Unix Shell Scripting
# ETL Tools: Informatica-Power Center 9.6, Datastage
# Version Control Tools: Cleacase, clearquest, SVN, Jira
# PROFESSIONAL EXPERIENCE:
# Confidential, NY
# Sr. Oracle Developer /Data Architect
# ['Involved in design and implementation of data warehouse environment including database architecture, metadata, and repository creation, technical specifications, Logical and physical data modeling, dimensional modeling, star schema , fact and dimensions', 'Design and development of reporting database, source system analysis and mapping entities from source to target, loading data from various source system onto an ETL layer and then cleansed, scrubbed for anomalies, business transformation logic applied and transformed data is then loaded onto staging layer in the Database.', 'Responsible for designing database structures, Oracle 11.2 SQL and PLSQL code development writing and restructuring packages, procedures & functions, using collections, analytical functions, implementing data masking to establish business rules', 'Reviewing and restructuring sql queries & PLSQL code, join strategies, indexes & table partitions, reviewing explain plan, hints, query execution plans, AWR reports, parallel loading techniques using staging tables, implementing data compression on large tables', 'Interacting with architect and support team for design and development of solutions using technologies like Hadoop, MapReduce, Cassandra etc.', 'Troubleshoot database issues in UAT and production environments']
# Environment: Oracle 12/11.2, NoSQL DB-Cassandra, MapReduce, Toad, SQL Navigator, Erwin, MS Visual Studio, Relational ClearQuest, Clearcase, MS-Visio, Unix shell scripting, Data Pump, Autosys
# Confidential, Hoboken, NJ
# Sr. Oracle Developer
# ['Involved in various phases of development lifecycle, requirements gathering, understanding business processes, source system analysis, creating logical and physical Data models, defining data quality and data profiling techniques, creating Source file layout mapping specifications & metadata repository', 'As a Database Technical Lead, responsible for designing database structures, Oracle 11.2 SQL and PLSQL code development, writing packages, procedures/functions and triggers, analytical functions, managing join strategies, performance indexes & table partitions, data masking using data redaction', 'Responsible for Sql query optimization & PLSQL code tuning using Explain Plan, gathering statistics, monitoring database performance using OEM, AWR reports', 'Experience in defining high volume data load using exchange partition technique, loading data from various source file formats (csv, xml, txt, excel, unstructured data) using external tables, Sql*Loader, Utl file, utilities like export import and Data Pump, scheduling jobs,', 'Creating OBIEE RPDs for the data structures, designing dashboards and reporting queries, configuring reporting schedules for business users', 'Providing support for ETL processes, test plans and integration testing, production support (24/7) for resolving critical data issues managing, mentoring development team', 'Monitoring progress of development and testing activities using Agile methodology, daily status call, tracking project deliverables']
# Environment: Oracle 12.2/11.2, Informatica 9.6,, Toad, SQL Navigator, OBIEE 11g, Erwin, MS Visual Studio, MS-Visio, Unix shell scripting, Data Pump, Autosys
# Confidential, Warren, NJ
# Oracle Developer-DBA
# ['Involved in gathering business requirements, liaising with Finance, Risk, Technology and FRO teams across the organizations, developing the end-to-end data warehouse solution architecture and documenting the technical specifications, build and manage Logical and Physical Data Model, designing extraction and loading techniques from various source systems like Oracle, Netezza, Teradata, Sybase', 'Defined and documented source to target mappings, attributes, data types, cardinality, data quality standards for banking products namely -Deposits, Mortgages, Securities, Loans, Derivatives for both wholesale and Retail.', 'Responsible for Oracle 10g/11g Sql & PLSQL code development, procedures, functions, packages, procedures, cursors, collections methods, bulk binding technique, managing indexes and table partitions, managing indexes and partitions', 'Involved in SQL query optimization & PLSQL code tuning using Explain Plan, gathering statistics, SQL Analyzer and tuning packs for performance monitoring.', 'Experience using Oracle Data Pump, SQL *Loader, Unix shell scripting, Autosys, Creating and managing reports using Business Objects, MS-Excel, familiar with Oracle Exadata architecture', 'Technical lead, supervising progress of development and testing activities using Agile methodology, tracking project deliverables, monitoring milestones in daily status call', 'Developing quality assurance / User Acceptance test plans, providing support to testing teams in System test & user acceptance testing phases, Implementation & production phase, post production roll out phase']
# Environment: Oracle 11g, Teradata 13.10, Erwin, Relational ClearQuest, Clearcase, MS-Visio, unix shell scripting, Autosys, File management- SVN &Perforce
# Confidential
# Data Architect
# ['As Data Architect, actively involved in gathering requirements, data analysis,logical and physical data modeling', 'Involved in preparing functional and technical design documents, source to target mapping, ETL mapping specification, data cleansing and profiling data, developing reusable components & services, Source data extraction from Sybase, Sql Server and Teradata, Netezza', 'As a Development lead - creating Oracle stored procedures, functions, packages, triggers, reviewing indexes and join strategies, managing table partitions, data masking for formatting and handling sensitive financial data, reviewing execution plans for sql query tuning and optimization', 'Map data between source systems, data warehouses, and data marts, creating new reports using Business objects, maintain existing reports including selection criteria and documentation', 'Developing test plans, providing support to testing teams in System test & user acceptance testing phases, implementation & production phase, post production roll out phase', 'Providing technical guidance to project teams throughout the software development life-cycle.']
# Environment: oracle 11.2/ 10.2, Teradata 13/13.10, Fastload, Multiload,, Erwin, Relational ClearQuest, Clearcase, MS-Visio, DataStage, Informatica Power Center 9.1, Erwin, Reporting tool Business Object, unix shell scripting, Tivoli Scheduler
# Confidential, NYC
# Oracle Development-DBA
# ['Involved in various phases of development lifecycle, from gathering requirements, designing and creating logical/physical data models based on business requirements, technical design specifications', 'Designed, developed and successfully implemented in-house PL/SQL coded ETL (Extraction, Transformation & Loading) process for the highly complex reporting system.', 'Data-migration lead DBA/analyst responsible for getting government agencies on-board “City time” including the likes of NYPD, FDNY and other agencies', 'As Database Lead Developer - responsible for Oracle 10g Sql & PLSQL code development, writing and reviewing procedures, functions, packages, procedures, using cursors, collections & bulk binding technique, managing indexes and table partitions,reviewing execution plans for query tuning and optimization', 'Managing indexes, materialized views, table and index partitions (local indexes), ETL processes, designing Business Objects universes and complex reports', 'Involved in SQL query optimization & PLSQL code tuning using Explain Plan, using oracle utilities like Data Pump, SQL*Loader for loading data', 'Maintaining database schema objects, version control, configuration & release management, tracking all changes to database objects using ClearQuest, Clearcase']
# Environment: Oracle 10.2/11.2, SQL, PL/SQL, TOAD, Teradata 12.0, DataPump, Import/Export Scripts, Erwin, Relational ClearQuest, ClearCase, Informatica (7.1 & 8.5.1), Business Objects, unix shell scripting.
# Confidential, Stamfor, Connecticut
# Oracle Developer - Legal and Compliance
# ['Involved in designing and developing Oracle 10g database schema objects Oracle PL/SQL packages, functions, and procedures, triggers', 'Extensively used advanced PLSQL techniques, collection methods, bulk binding techniques, Ref Cursors, dynamic SQL in PL/SQL, managing joins, indexes, table partitions, materialized views and logs', 'Managed database security through user administration and granting correct roles and privileges, using data masking techniques', 'Experience working with large volumes of data, using exchange partition, loading export import, Sql*Loader utilities', 'Providing support in testing, deployment and implementation phase.', 'In-depth experience with Unix operating systems, shell scripts']
# Environment: Oracle 9i/10.2, SQL, PL/SQL, TOAD, data Guard, DataPump, SQL-Backtrack, SQL*Loader/Import /Export Scripts, Erwin, Informatica (6.1)
# Confidential
# Programmer (Oracle Developer)
# ['Developing and creating schema objects, coding procedures, functions, triggers, packages, cursors, dynamic Sql, bulk binding techniques using oracle 9i.', 'Managing Indexes, materialized views and table partitions, user privileges and access.', 'Managing Test Databases for testing and data analysis .']
# Environment: Sun Solaris 7, Oracle 9i/8i, Oracle Enterprise Manager Diagnostics Pack and Tuning pack, RMAN, SQL, PL/SQL, shell scripting, SQL*Loader/Import/Export Scripts, Erwin, Toad
# Confidential
# Programmer
# ['Involved in analysis, design and development of the system', 'Created database objects tables, indexes, views, synonyms, stored procedures, functions, triggers, implementing and maintaining integrity constraints, indexes on database tables, created Forms and reports using Visual Basic.', 'Performed testing and debugging, preparing documentation and providing user training']
# Environment: Oracle 7.3, SQL, PL/SQL, Visual Basic 5.0, Crystal Reports

# %%
from typing import List, Optional, Dict, Any
from pydantic import BaseModel
from enum import Enum

class SectionType(Enum):
    SUMMARY = "summary"
    TECHNICAL_SKILLS = "technical_skills"
    PROFESSIONAL_EXPERIENCE = "professional_experience"
    UNKNOWN = "unknown"

class Experience(BaseModel):
    company: str
    job_role: str
    responsibilities: List[str]
    environment: Optional[str] = None

class Resume(BaseModel):
    job_role: str
    professional_summary: List[str]
    technical_skills: List[str]
    experiences: List[Experience]

class SectionTracker:
    def __init__(self):
        self.current_section = SectionType.UNKNOWN
        self.section_boundaries = {
            SectionType.SUMMARY: ("SUMMARY:", "TECHNICAL SKILLS:"),
            SectionType.TECHNICAL_SKILLS: ("TECHNICAL SKILLS:", "PROFESSIONAL EXPERIENCE:"),
            SectionType.PROFESSIONAL_EXPERIENCE: ("PROFESSIONAL EXPERIENCE:", None)
        }
    
    def update_section(self, text: str) -> bool:
        """Update current section based on text content"""
        text_upper = text.upper().strip()
        
        for section, (start_marker, end_marker) in self.section_boundaries.items():
            if start_marker and text_upper.startswith(start_marker):
                self.current_section = section
                return True
            elif end_marker and text_upper.startswith(end_marker):
                self.current_section = SectionType(section.value)
                return True
        
        return False

class ExperienceBuilder:
    def __init__(self):
        self.reset()
    
    def reset(self):
        self.current_company = None
        self.current_role = None
        self.current_responsibilities = []
        self.current_environment = None
        self.is_building = False
    
    def start_experience(self, company: str):
        """Start a new experience block"""
        self.reset()
        self.current_company = company
        self.is_building = True
    
    def set_role(self, role: str):
        """Set the job role for current experience"""
        self.current_role = role
    
    def add_responsibility(self, responsibility: str):
        """Add responsibility to current experience"""
        self.current_responsibilities.append(responsibility)
    
    def set_environment(self, environment: str):
        """Set environment for current experience"""
        self.current_environment = environment
    
    def build(self) -> Optional[Experience]:
        """Build and return the experience if valid"""
        if (self.is_building and self.current_company and 
            self.current_role and self.current_responsibilities):
            return Experience(
                company=self.current_company,
                job_role=self.current_role,
                responsibilities=self.current_responsibilities.copy(),
                environment=self.current_environment
            )
        return None

class JSONResumeMerger:
    def __init__(self):
        self.section_tracker = SectionTracker()
        self.experience_builder = ExperienceBuilder()
        self.resume_data = {
            'professional_summary': [],
            'technical_skills': [],
            'experiences': []
        }
    
    def is_confidential_company(self, text: str) -> bool:
        """Check if text indicates a confidential company"""
        return text.upper().startswith("CONFIDENTIAL")
    
    def is_environment_line(self, text: str) -> bool:
        """Check if text is an environment line"""
        return text.upper().startswith("ENVIRONMENT:")
    
    def extract_environment(self, text: str) -> str:
        """Extract environment from environment line"""
        if ":" in text:
            return text.split(":", 1)[1].strip()
        return text.strip()
    
    def process_structured_content(self, structured_content: List[Dict[str, Any]]) -> Resume:
        """Process structured content and build resume"""
        
        i = 0
        while i < len(structured_content):
            item = structured_content[i]
            
            # Update section tracker
            if item['type'] == 'p':
                self.section_tracker.update_section(item['text'])
            
            # Process based on current section
            if self.section_tracker.current_section == SectionType.SUMMARY:
                self._process_summary_section(item)
            
            elif self.section_tracker.current_section == SectionType.TECHNICAL_SKILLS:
                self._process_technical_skills_section(item)
            
            elif self.section_tracker.current_section == SectionType.PROFESSIONAL_EXPERIENCE:
                i = self._process_experience_section(structured_content, i)
            
            i += 1
        
        # Build any remaining experience
        self._finalize_current_experience()
        
        return Resume(**self.resume_data)
    
    def _process_summary_section(self, item: Dict[str, Any]):
        """Process items in summary section"""
        if item['type'] == 'ul':
            self.resume_data['professional_summary'].extend(item['items'])
    
    def _process_technical_skills_section(self, item: Dict[str, Any]):
        """Process items in technical skills section"""
        if item['type'] == 'p' and not item['text'].upper().startswith("TECHNICAL SKILLS:"):
            self.resume_data['technical_skills'].append(item['text'])
    
    def _process_experience_section(self, structured_content: List[Dict[str, Any]], current_index: int) -> int:
        """Process professional experience section"""
        item = structured_content[current_index]
        
        if item['type'] == 'p':
            text = item['text']
            
            # Check for confidential company
            if self.is_confidential_company(text):
                self._finalize_current_experience()
                self.experience_builder.start_experience(text)
            
            # Check for job role (next P tag after confidential)
            elif (self.experience_builder.is_building and 
                  not self.experience_builder.current_role and
                  not self.is_confidential_company(text) and
                  not self.is_environment_line(text)):
                self.experience_builder.set_role(text)
            
            # Check for environment
            elif self.is_environment_line(text):
                environment = self.extract_environment(text)
                self.experience_builder.set_environment(environment)
        
        # Process responsibilities from UL tags
        elif item['type'] == 'ul' and self.experience_builder.is_building:
            for responsibility in item['items']:
                self.experience_builder.add_responsibility(responsibility)
            
            # Check if next item is environment or new experience
            if current_index + 1 < len(structured_content):
                next_item = structured_content[current_index + 1]
                if (next_item['type'] == 'p' and 
                    (self.is_environment_line(next_item['text']) or 
                     self.is_confidential_company(next_item['text']))):
                    self._finalize_current_experience()
        
        return current_index
    
    def _finalize_current_experience(self):
        """Finalize and add current experience to resume data"""
        experience = self.experience_builder.build()
        if experience:
            self.resume_data['experiences'].append(experience)
        self.experience_builder.reset()

# Usage example
def merge_json_resume(json_data: Dict[str, Any]) -> Resume:
    """Main function to merge JSON resume data"""
    merger = JSONResumeMerger()
    
    if 'structured_content' in json_data:
        return merger.process_structured_content(json_data['structured_content'])
    else:
        raise ValueError("No structured_content found in JSON data")

# Example usage with your sample data
if __name__ == "__main__":
    # Your sample JSON data would be loaded here
    sample_json = result
    
    try:
        resume = merge_json_resume(sample_json)
        
        # Print results
        print("PROFESSIONAL SUMMARY:")
        for summary in resume.professional_summary:
            print(f"- {summary}")
        
        print("\nTECHNICAL SKILLS:")
        for skill in resume.technical_skills:
            print(f"- {skill}")
        
        print("\nEXPERIENCES:")
        for exp in resume.experiences:
            print(f"\nCompany: {exp.company}")
            print(f"Role: {exp.job_role}")
            print("Responsibilities:")
            for resp in exp.responsibilities:
                print(f"  - {resp}")
            if exp.environment:
                print(f"Environment: {exp.environment}")
                
    except Exception as e:
        print(f"Error processing resume: {e}")
# Out:
# PROFESSIONAL SUMMARY:
# - Over 18 years of experience in Application design, development and data architecture on a wide variety of platforms, operating systems and databases mainly in Banking and Finance domain.
# - Extensive experience managing and supporting multiple projects involving design and development of OLTP & Data warehouse databases in Oracle 12c/11.2/10g , Teradata, Netezza, NoSQL databases - Cassandra , SQL Server across multiple industries such as Banking, Insurance, Financial, Taxation.
# - More than 8 years of experience as D ata architect involved in design and implementation of database solutions, data integration techniques, D ata modeling , Master Data management & data governance, data quality/data profiling techniques
# - Extensive experience in Oracle Sql & PLSQL code development, writing and reviewing procedures, functions, packages , managing indexes and partitions , reviewing execution plans for query tuning and optimization, OEM database monitoring, OBIEE repositories and dashboards
# - Experience handling high volume data load using SQL*Loade r, external tables, exchange partition, Oracle Data Pump, Implemented data compression in Oracle Exadata to reduce storage and improve performance for certain queries in Oracle Exadata
# - Providing technical guidance to project teams in all phases of SLDC, creating test cases and providing support during testing and implementation, UI integration and production releases
# - Experience in handling ETL tools like Informatica, Datastage, Unix shells scripting
# - Familiar with Hadoop information architecture, NoSql Database - Caasandra
# - As Technical lead supervising progress of development and testing activities using Agile methodology, daily status call, tracking project deliverables
# - Excellent communication and interpersonal skills.
#
# TECHNICAL SKILLS:
# - PROFESSIONAL EXPERIENCE:
# - Confidential, NY
# - Sr. Oracle Developer /Data Architect
# - Environment: Oracle 12/11.2, NoSQL DB-Cassandra, MapReduce, Toad, SQL Navigator, Erwin, MS Visual Studio, Relational ClearQuest, Clearcase, MS-Visio, Unix shell scripting, Data Pump, Autosys
# - Confidential, Hoboken, NJ
# - Sr. Oracle Developer
# - Environment: Oracle 12.2/11.2, Informatica 9.6,, Toad, SQL Navigator, OBIEE 11g, Erwin, MS Visual Studio, MS-Visio, Unix shell scripting, Data Pump, Autosys
# - Confidential, Warren, NJ
# - Oracle Developer-DBA
# - Environment: Oracle 11g, Teradata 13.10, Erwin, Relational ClearQuest, Clearcase, MS-Visio, unix shell scripting, Autosys, File management- SVN &Perforce
# - Confidential
# - Data Architect
# - Environment: oracle 11.2/ 10.2, Teradata 13/13.10, Fastload, Multiload,, Erwin, Relational ClearQuest, Clearcase, MS-Visio, DataStage, Informatica Power Center 9.1, Erwin, Reporting tool Business Object, unix shell scripting, Tivoli Scheduler
# - Confidential, NYC
# - Oracle Development-DBA
# - Environment: Oracle 10.2/11.2, SQL, PL/SQL, TOAD, Teradata 12.0, DataPump, Import/Export Scripts, Erwin, Relational ClearQuest, ClearCase, Informatica (7.1 & 8.5.1), Business Objects, unix shell scripting.
# - Confidential, Stamfor, Connecticut
# - Oracle Developer - Legal and Compliance
# - Environment: Oracle 9i/10.2, SQL, PL/SQL, TOAD, data Guard, DataPump, SQL-Backtrack, SQL*Loader/Import /Export Scripts, Erwin, Informatica (6.1)
# - Confidential
# - Programmer (Oracle Developer)
# - Environment: Sun Solaris 7, Oracle 9i/8i, Oracle Enterprise Manager Diagnostics Pack and Tuning pack, RMAN, SQL, PL/SQL, shell scripting, SQL*Loader/Import/Export Scripts, Erwin, Toad
# - Confidential
# - Programmer
# - Environment: Oracle 7.3, SQL, PL/SQL, Visual Basic 5.0, Crystal Reports
#
# EXPERIENCES:

# %%
new_json = {}
section = None
for item in result['structured_content']:
    if item.get("type") == "p" and section != "TECHNICAL SKILLS:" and section != "PROFESSIONAL EXPERIENCE:":
        section = item.get("text").lower().strip()
        new_json[section] = []
    elif item.get("type") == "p" and section == "technical skills" and item.get("text").lower().strip() != "technical skills:":
        new_json[section].extend(item.get("text"))
    elif item.get("type") == "ul":
        new_json[section].extend(item.get("items"))

# %%
def parse_resume(json_data):
    # Initialize the resume structure
    resume = {
        "professional_summary": [],
        "technical_skills": [],
        "experiences": []
    }
    
    structured_content = json_data.get("structured_content", [])
    
    # Flags to track current section
    in_summary = False
    in_technical_skills = False
    in_professional_experience = False
    
    # Variables for experience parsing
    current_experience = None
    current_job_role = None
    current_responsibilities = []
    current_environment = None
    
    # Iterate through each element in structured_content
    i = 0
    while i < len(structured_content):
        element = structured_content[i]
        
        # Check if we're entering SUMMARY section
        if element["type"] == "p" and "SUMMARY" in element["text"]:
            in_summary = True
            in_technical_skills = False
            in_professional_experience = False
            i += 1
            continue
        
        # Check if we're entering TECHNICAL SKILLS section
        elif element["type"] == "p" and "TECHNICAL SKILLS" in element["text"]:
            in_summary = False
            in_technical_skills = True
            in_professional_experience = False
            i += 1
            continue
        
        # Check if we're entering PROFESSIONAL EXPERIENCE section
        elif element["type"] == "p" and "PROFESSIONAL EXPERIENCE" in element["text"]:
            in_summary = False
            in_technical_skills = False
            in_professional_experience = True
            i += 1
            continue
        
        # Process SUMMARY section
        elif in_summary:
            if element["type"] == "ul":
                resume["professional_summary"].extend(element["items"])
            i += 1
            continue
        
        # Process TECHNICAL SKILLS section
        elif in_technical_skills:
            if element["type"] == "p":
                # Skip the "TECHNICAL SKILLS:" header itself
                if "TECHNICAL SKILLS" not in element["text"]:
                    resume["technical_skills"].append(element["text"])
            i += 1
            continue
        
        # Process PROFESSIONAL EXPERIENCE section
        elif in_professional_experience:
            # Check for "Confidential" P tags to identify new experiences
            if element["type"] == "p" and "Confidential" in element["text"]:
                # Save previous experience if it exists
                if current_experience is not None:
                    experience_data = {
                        "job_role": current_job_role,
                        "responsibilities": current_responsibilities.copy()
                    }
                    if current_environment:
                        experience_data["environment"] = current_environment
                    resume["experiences"].append(experience_data)
                
                # Reset for new experience
                current_job_role = None
                current_responsibilities = []
                current_environment = None
                
                # The next P tag after "Confidential" should be the job role
                if i + 1 < len(structured_content):
                    next_element = structured_content[i + 1]
                    if next_element["type"] == "p":
                        current_job_role = next_element["text"]
                        i += 2  # Skip both confidential and job role
                    else:
                        i += 1
                else:
                    i += 1
                continue
            
            # Check for UL tags (responsibilities)
            elif element["type"] == "ul" and current_job_role:
                current_responsibilities.extend(element["items"])
                i += 1
                continue
            
            # Check for "Environment" P tags
            elif element["type"] == "p" and "Environment:" in element["text"]:
                current_environment = element["text"].replace("Environment:", "").strip()
                i += 1
                continue
            
            # Regular P tag in experience section (might be environment or other info)
            elif element["type"] == "p":
                # If we don't have a job role yet but we're in an experience, this might be it
                if not current_job_role and "Confidential" not in element["text"]:
                    current_job_role = element["text"]
                i += 1
                continue
            
            else:
                i += 1
                continue
        
        else:
            i += 1
            continue
    
    # Don't forget to add the last experience
    if current_job_role:
        experience_data = {
            "job_role": current_job_role,
            "responsibilities": current_responsibilities.copy()
        }
        if current_environment:
            experience_data["environment"] = current_environment
        resume["experiences"].append(experience_data)
    
    return resume

# Alternative version that returns a Resume object (if you want to use the Pydantic model)
def parse_resume_to_object(json_data):
    parsed_data = parse_resume(json_data)
    return Resume(**parsed_data)

# Usage example:
if __name__ == "__main__":
    # Assuming your JSON data is in a variable called 'sample_json'
    resume_data = parse_resume(result)
    
    # Print the results to verify
    print("PROFESSIONAL SUMMARY:")
    for item in resume_data["professional_summary"]:
        print(f"- {item}")
    
    print("\nTECHNICAL SKILLS:")
    for skill in resume_data["technical_skills"]:
        print(f"- {skill}")
    
    print("\nEXPERIENCES:")
    for exp in resume_data["experiences"]:
        print(f"\nJob Role: {exp['job_role']}")
        if 'environment' in exp:
            print(f"Environment: {exp['environment']}")
        print("Responsibilities:")
        for resp in exp['responsibilities']:
            print(f"- {resp}")
# Out:
# PROFESSIONAL SUMMARY:
# - Over 18 years of experience in Application design, development and data architecture on a wide variety of platforms, operating systems and databases mainly in Banking and Finance domain.
# - Extensive experience managing and supporting multiple projects involving design and development of OLTP & Data warehouse databases in Oracle 12c/11.2/10g , Teradata, Netezza, NoSQL databases - Cassandra , SQL Server across multiple industries such as Banking, Insurance, Financial, Taxation.
# - More than 8 years of experience as D ata architect involved in design and implementation of database solutions, data integration techniques, D ata modeling , Master Data management & data governance, data quality/data profiling techniques
# - Extensive experience in Oracle Sql & PLSQL code development, writing and reviewing procedures, functions, packages , managing indexes and partitions , reviewing execution plans for query tuning and optimization, OEM database monitoring, OBIEE repositories and dashboards
# - Experience handling high volume data load using SQL*Loade r, external tables, exchange partition, Oracle Data Pump, Implemented data compression in Oracle Exadata to reduce storage and improve performance for certain queries in Oracle Exadata
# - Providing technical guidance to project teams in all phases of SLDC, creating test cases and providing support during testing and implementation, UI integration and production releases
# - Experience in handling ETL tools like Informatica, Datastage, Unix shells scripting
# - Familiar with Hadoop information architecture, NoSql Database - Caasandra
# - As Technical lead supervising progress of development and testing activities using Agile methodology, daily status call, tracking project deliverables
# - Excellent communication and interpersonal skills.
#
# TECHNICAL SKILLS:
# - RDBMS: ORACLE 12.2/11.2/10 g/9i, Teradata, Netezza, SQL Server, Access, Hadoop ecosystem Hive, MapReduce, NoSQL DB- Cassandra
# - Tools: SQL, PLSQL, Oracle Enterprise Manager, OBIEE 11g, SQL* Loader, DataPump, Export and Import Utilities, Erwin, TOAD, Rational Clearcase, ClearQuest, Business Object, Cognos
# - Scripting Languages: Python, SQL, PL/SQL, SQL*Plus, Unix Shell Scripting
# - ETL Tools: Informatica-Power Center 9.6, Datastage
# - Version Control Tools: Cleacase, clearquest, SVN, Jira
#
# EXPERIENCES:
#
# Job Role: Programmer
# Environment: Oracle 7.3, SQL, PL/SQL, Visual Basic 5.0, Crystal Reports
# Responsibilities:
# - Involved in analysis, design and development of the system
# - Created database objects tables, indexes, views, synonyms, stored procedures, functions, triggers, implementing and maintaining integrity constraints, indexes on database tables, created Forms and reports using Visual Basic.
# - Performed testing and debugging, preparing documentation and providing user training

# %% [markdown]
# ### Parser

# %%
def parse_resume(json_data):
    # Initialize the resume structure
    resume = {
        "professional_summary": [],
        "technical_skills": [],
        "experiences": []
    }
    
    structured_content = json_data.get("structured_content", [])
    
    # Flags to track current section
    in_summary = False
    in_technical_skills = False
    in_professional_experience = False
    
    # Variables for experience parsing
    current_experience = None
    current_job_role = None
    current_responsibilities = []
    current_environment = None
    experience_started = False
    
    # Iterate through each element in structured_content
    i = 0
    while i < len(structured_content):
        element = structured_content[i]
        
        # Check if we're entering SUMMARY section
        if element["type"] == "p" and "SUMMARY" in element["text"]:
            in_summary = True
            in_technical_skills = False
            in_professional_experience = False
            i += 1
            continue
        
        # Check if we're entering TECHNICAL SKILLS section
        elif element["type"] == "p" and "TECHNICAL SKILLS" in element["text"]:
            in_summary = False
            in_technical_skills = True
            in_professional_experience = False
            i += 1
            continue
        
        # Check if we're entering PROFESSIONAL EXPERIENCE section
        elif element["type"] == "p" and "PROFESSIONAL EXPERIENCE" in element["text"]:
            in_summary = False
            in_technical_skills = False
            in_professional_experience = True
            i += 1
            continue
        
        # Process SUMMARY section
        elif in_summary:
            if element["type"] == "ul":
                resume["professional_summary"].extend(element["items"])
            i += 1
            continue
        
        # Process TECHNICAL SKILLS section
        elif in_technical_skills:
            if element["type"] == "p":
                # Skip the "TECHNICAL SKILLS:" header itself
                if "TECHNICAL SKILLS" not in element["text"]:
                    resume["technical_skills"].append(element["text"])
            i += 1
            continue
        
        # Process PROFESSIONAL EXPERIENCE section
        elif in_professional_experience:
            # Check for "Confidential" P tags to identify new experiences
            if element["type"] == "p" and "Confidential" in element["text"]:
                # Save previous experience if it exists and has data
                if experience_started and current_job_role:
                    experience_data = {
                        "job_role": current_job_role,
                        "responsibilities": current_responsibilities.copy()
                    }
                    if current_environment:
                        experience_data["environment"] = current_environment
                    resume["experiences"].append(experience_data)
                
                # Reset for new experience
                current_job_role = None
                current_responsibilities = []
                current_environment = None
                experience_started = True
                
                # The next P tag after "Confidential" should be the job role
                if i + 1 < len(structured_content):
                    next_element = structured_content[i + 1]
                    if next_element["type"] == "p":
                        current_job_role = next_element["text"]
                        i += 2  # Skip both confidential and job role
                    else:
                        i += 1
                else:
                    i += 1
                continue
            
            # Check for UL tags (responsibilities)
            elif element["type"] == "ul" and current_job_role:
                current_responsibilities.extend(element["items"])
                i += 1
                continue
            
            # Check for "Environment" P tags
            elif element["type"] == "p" and "Environment:" in element["text"]:
                current_environment = element["text"].replace("Environment:", "").strip()
                i += 1
                continue
            
            # Check for "Environment" without colon (some entries might have different formatting)
            elif element["type"] == "p" and "Environment" in element["text"] and current_job_role:
                current_environment = element["text"].replace("Environment", "").strip()
                if current_environment.startswith(":"):
                    current_environment = current_environment[1:].strip()
                i += 1
                continue
            
            # Regular P tag in experience section (might be environment or other info)
            elif element["type"] == "p":
                # If we don't have a job role yet but we're in an experience, this might be it
                if not current_job_role and "Confidential" not in element["text"] and "PROFESSIONAL EXPERIENCE" not in element["text"]:
                    current_job_role = element["text"]
                i += 1
                continue
            
            else:
                i += 1
                continue
        
        else:
            i += 1
            continue
    
    # Don't forget to add the last experience if it exists
    if experience_started and current_job_role:
        experience_data = {
            "job_role": current_job_role,
            "responsibilities": current_responsibilities.copy()
        }
        if current_environment:
            experience_data["environment"] = current_environment
        resume["experiences"].append(experience_data)
    
    return resume

# Alternative version that returns a Resume object
def parse_resume_to_object(json_data):
    parsed_data = parse_resume(json_data)
    return Resume(**parsed_data)

# Usage example:
if __name__ == "__main__":
    # Assuming your JSON data is in a variable called 'sample_json'
    resume_data = parse_resume(result)
    with open("structured_resume.json", "w") as f:
        json.dump(resume_data, f, indent=4)
    
    # Print the results to verify
    print("PROFESSIONAL SUMMARY:")
    for item in resume_data["professional_summary"]:
        print(f"- {item}")
    
    print("\nTECHNICAL SKILLS:")
    for skill in resume_data["technical_skills"]:
        print(f"- {skill}")
    
    print("\nEXPERIENCES:")
    for idx, exp in enumerate(resume_data["experiences"]):
        #print(f"\n--- Experience {idx + 1} ---")
        print("\n")
        print(f"Job Role: {exp['job_role']}")
        if 'environment' in exp:
            print(f"Environment: {exp['environment']}")
        print("Responsibilities:")
        for resp in exp['responsibilities']:
            print(f"- {resp}")
# Out:
# PROFESSIONAL SUMMARY:
# - Over 18 years of experience in Application design, development and data architecture on a wide variety of platforms, operating systems and databases mainly in Banking and Finance domain.
# - Extensive experience managing and supporting multiple projects involving design and development of OLTP & Data warehouse databases in Oracle 12c/11.2/10g , Teradata, Netezza, NoSQL databases - Cassandra , SQL Server across multiple industries such as Banking, Insurance, Financial, Taxation.
# - More than 8 years of experience as D ata architect involved in design and implementation of database solutions, data integration techniques, D ata modeling , Master Data management & data governance, data quality/data profiling techniques
# - Extensive experience in Oracle Sql & PLSQL code development, writing and reviewing procedures, functions, packages , managing indexes and partitions , reviewing execution plans for query tuning and optimization, OEM database monitoring, OBIEE repositories and dashboards
# - Experience handling high volume data load using SQL*Loade r, external tables, exchange partition, Oracle Data Pump, Implemented data compression in Oracle Exadata to reduce storage and improve performance for certain queries in Oracle Exadata
# - Providing technical guidance to project teams in all phases of SLDC, creating test cases and providing support during testing and implementation, UI integration and production releases
# - Experience in handling ETL tools like Informatica, Datastage, Unix shells scripting
# - Familiar with Hadoop information architecture, NoSql Database - Caasandra
# - As Technical lead supervising progress of development and testing activities using Agile methodology, daily status call, tracking project deliverables
# - Excellent communication and interpersonal skills.
#
# TECHNICAL SKILLS:
# - RDBMS: ORACLE 12.2/11.2/10 g/9i, Teradata, Netezza, SQL Server, Access, Hadoop ecosystem Hive, MapReduce, NoSQL DB- Cassandra
# - Tools: SQL, PLSQL, Oracle Enterprise Manager, OBIEE 11g, SQL* Loader, DataPump, Export and Import Utilities, Erwin, TOAD, Rational Clearcase, ClearQuest, Business Object, Cognos
# - Scripting Languages: Python, SQL, PL/SQL, SQL*Plus, Unix Shell Scripting
# - ETL Tools: Informatica-Power Center 9.6, Datastage
# - Version Control Tools: Cleacase, clearquest, SVN, Jira
#
# EXPERIENCES:
#
#
# Job Role: Sr. Oracle Developer /Data Architect
# Environment: Oracle 12/11.2, NoSQL DB-Cassandra, MapReduce, Toad, SQL Navigator, Erwin, MS Visual Studio, Relational ClearQuest, Clearcase, MS-Visio, Unix shell scripting, Data Pump, Autosys
# Responsibilities:
# - Involved in design and implementation of data warehouse environment including database architecture, metadata, and repository creation, technical specifications, Logical and physical data modeling, dimensional modeling, star schema , fact and dimensions
# - Design and development of reporting database, source system analysis and mapping entities from source to target, loading data from various source system onto an ETL layer and then cleansed, scrubbed for anomalies, business transformation logic applied and transformed data is then loaded onto staging layer in the Database.
# - Responsible for designing database structures, Oracle 11.2 SQL and PLSQL code development writing and restructuring packages, procedures & functions, using collections, analytical functions, implementing data masking to establish business rules
# - Reviewing and restructuring sql queries & PLSQL code, join strategies, indexes & table partitions, reviewing explain plan, hints, query execution plans, AWR reports, parallel loading techniques using staging tables, implementing data compression on large tables
# - Interacting with architect and support team for design and development of solutions using technologies like Hadoop, MapReduce, Cassandra etc.
# - Troubleshoot database issues in UAT and production environments
#
#
# Job Role: Sr. Oracle Developer
# Environment: Oracle 12.2/11.2, Informatica 9.6,, Toad, SQL Navigator, OBIEE 11g, Erwin, MS Visual Studio, MS-Visio, Unix shell scripting, Data Pump, Autosys
# Responsibilities:
# - Involved in various phases of development lifecycle, requirements gathering, understanding business processes, source system analysis, creating logical and physical Data models, defining data quality and data profiling techniques, creating Source file layout mapping specifications & metadata repository
# - As a Database Technical Lead, responsible for designing database structures, Oracle 11.2 SQL and PLSQL code development, writing packages, procedures/functions and triggers, analytical functions, managing join strategies, performance indexes & table partitions, data masking using data redaction
# - Responsible for Sql query optimization & PLSQL code tuning using Explain Plan, gathering statistics, monitoring database performance using OEM, AWR reports
# - Experience in defining high volume data load using exchange partition technique, loading data from various source file formats (csv, xml, txt, excel, unstructured data) using external tables, Sql*Loader, Utl file, utilities like export import and Data Pump, scheduling jobs,
# - Creating OBIEE RPDs for the data structures, designing dashboards and reporting queries, configuring reporting schedules for business users
# - Providing support for ETL processes, test plans and integration testing, production support (24/7) for resolving critical data issues managing, mentoring development team
# - Monitoring progress of development and testing activities using Agile methodology, daily status call, tracking project deliverables
#
#
# Job Role: Oracle Developer-DBA
# Environment: Oracle 11g, Teradata 13.10, Erwin, Relational ClearQuest, Clearcase, MS-Visio, unix shell scripting, Autosys, File management- SVN &Perforce
# Responsibilities:
# - Involved in gathering business requirements, liaising with Finance, Risk, Technology and FRO teams across the organizations, developing the end-to-end data warehouse solution architecture and documenting the technical specifications, build and manage Logical and Physical Data Model, designing extraction and loading techniques from various source systems like Oracle, Netezza, Teradata, Sybase
# - Defined and documented source to target mappings, attributes, data types, cardinality, data quality standards for banking products namely -Deposits, Mortgages, Securities, Loans, Derivatives for both wholesale and Retail.
# - Responsible for Oracle 10g/11g Sql & PLSQL code development, procedures, functions, packages, procedures, cursors, collections methods, bulk binding technique, managing indexes and table partitions, managing indexes and partitions
# - Involved in SQL query optimization & PLSQL code tuning using Explain Plan, gathering statistics, SQL Analyzer and tuning packs for performance monitoring.
# - Experience using Oracle Data Pump, SQL *Loader, Unix shell scripting, Autosys, Creating and managing reports using Business Objects, MS-Excel, familiar with Oracle Exadata architecture
# - Technical lead, supervising progress of development and testing activities using Agile methodology, tracking project deliverables, monitoring milestones in daily status call
# - Developing quality assurance / User Acceptance test plans, providing support to testing teams in System test & user acceptance testing phases, Implementation & production phase, post production roll out phase
#
#
# Job Role: Data Architect
# Environment: oracle 11.2/ 10.2, Teradata 13/13.10, Fastload, Multiload,, Erwin, Relational ClearQuest, Clearcase, MS-Visio, DataStage, Informatica Power Center 9.1, Erwin, Reporting tool Business Object, unix shell scripting, Tivoli Scheduler
# Responsibilities:
# - As Data Architect, actively involved in gathering requirements, data analysis,logical and physical data modeling
# - Involved in preparing functional and technical design documents, source to target mapping, ETL mapping specification, data cleansing and profiling data, developing reusable components & services, Source data extraction from Sybase, Sql Server and Teradata, Netezza
# - As a Development lead - creating Oracle stored procedures, functions, packages, triggers, reviewing indexes and join strategies, managing table partitions, data masking for formatting and handling sensitive financial data, reviewing execution plans for sql query tuning and optimization
# - Map data between source systems, data warehouses, and data marts, creating new reports using Business objects, maintain existing reports including selection criteria and documentation
# - Developing test plans, providing support to testing teams in System test & user acceptance testing phases, implementation & production phase, post production roll out phase
# - Providing technical guidance to project teams throughout the software development life-cycle.
#
#
# Job Role: Oracle Development-DBA
# Environment: Oracle 10.2/11.2, SQL, PL/SQL, TOAD, Teradata 12.0, DataPump, Import/Export Scripts, Erwin, Relational ClearQuest, ClearCase, Informatica (7.1 & 8.5.1), Business Objects, unix shell scripting.
# Responsibilities:
# - Involved in various phases of development lifecycle, from gathering requirements, designing and creating logical/physical data models based on business requirements, technical design specifications
# - Designed, developed and successfully implemented in-house PL/SQL coded ETL (Extraction, Transformation & Loading) process for the highly complex reporting system.
# - Data-migration lead DBA/analyst responsible for getting government agencies on-board “City time” including the likes of NYPD, FDNY and other agencies
# - As Database Lead Developer - responsible for Oracle 10g Sql & PLSQL code development, writing and reviewing procedures, functions, packages, procedures, using cursors, collections & bulk binding technique, managing indexes and table partitions,reviewing execution plans for query tuning and optimization
# - Managing indexes, materialized views, table and index partitions (local indexes), ETL processes, designing Business Objects universes and complex reports
# - Involved in SQL query optimization & PLSQL code tuning using Explain Plan, using oracle utilities like Data Pump, SQL*Loader for loading data
# - Maintaining database schema objects, version control, configuration & release management, tracking all changes to database objects using ClearQuest, Clearcase
#
#
# Job Role: Oracle Developer - Legal and Compliance
# Environment: Oracle 9i/10.2, SQL, PL/SQL, TOAD, data Guard, DataPump, SQL-Backtrack, SQL*Loader/Import /Export Scripts, Erwin, Informatica (6.1)
# Responsibilities:
# - Involved in designing and developing Oracle 10g database schema objects Oracle PL/SQL packages, functions, and procedures, triggers
# - Extensively used advanced PLSQL techniques, collection methods, bulk binding techniques, Ref Cursors, dynamic SQL in PL/SQL, managing joins, indexes, table partitions, materialized views and logs
# - Managed database security through user administration and granting correct roles and privileges, using data masking techniques
# - Experience working with large volumes of data, using exchange partition, loading export import, Sql*Loader utilities
# - Providing support in testing, deployment and implementation phase.
# - In-depth experience with Unix operating systems, shell scripts
#
#
# Job Role: Programmer (Oracle Developer)
# Environment: Sun Solaris 7, Oracle 9i/8i, Oracle Enterprise Manager Diagnostics Pack and Tuning pack, RMAN, SQL, PL/SQL, shell scripting, SQL*Loader/Import/Export Scripts, Erwin, Toad
# Responsibilities:
# - Developing and creating schema objects, coding procedures, functions, triggers, packages, cursors, dynamic Sql, bulk binding techniques using oracle 9i.
# - Managing Indexes, materialized views and table partitions, user privileges and access.
# - Managing Test Databases for testing and data analysis .
#
#
# Job Role: Programmer
# Environment: Oracle 7.3, SQL, PL/SQL, Visual Basic 5.0, Crystal Reports
# Responsibilities:
# - Involved in analysis, design and development of the system
# - Created database objects tables, indexes, views, synonyms, stored procedures, functions, triggers, implementing and maintaining integrity constraints, indexes on database tables, created Forms and reports using Visual Basic.
# - Performed testing and debugging, preparing documentation and providing user training

# %%
resume_data = parse_resume(result)
with open("structured_resume.json", "w") as f:
    json.dump(resume_data, f, indent=4)

# Print the results to verify
print("PROFESSIONAL SUMMARY:")
for item in resume_data["professional_summary"]:
    print(f"- {item}")

print("\nTECHNICAL SKILLS:")
for skill in resume_data["technical_skills"]:
    print(f"- {skill}")

print("\nEXPERIENCES:")
for idx, exp in enumerate(resume_data["experiences"]):
    print(f"\n--- Experience {idx + 1} ---")
    print(f"Job Role: {exp['job_role']}")
    if 'environment' in exp:
        print(f"Environment: {exp['environment']}")
    print("Responsibilities:")
    for resp in exp['responsibilities']:
        print(f"- {resp}")
# Out:
# PROFESSIONAL SUMMARY:
# - 8+ years of profound working experience in SQL, PL/SQL programming, System Analysis, Design, Development, and Support of Oracle Database … in Production, Staging, Development, and Testing Environments.
# - Expertise in writing SQL queries, Views, Materialized views, PL/SQL procedures, functions, packages, triggers, cursors, collections, Ref cursor, cursor variables, System reference cursor , Dynamic SQL.
# - Experience in developing External Tables, Joins, Indexes, and Sequences.
# - Experience in query optimization, performance, and tuning (PL/SQL) using SQL Trace , Explain Plan, Indexing, Hints, Bulk Binds, Bulk Collect, Creation of global temporary tables and table partitioning.
# - Experience in using several built - in database packages such as DBMS JOB, DBMS OUTPUT , UTL FILE , and DBMS SQL to name a few.
# - Experience in all the phases of SDLC, including requirements gathering, system design, Development, Unit testing, Integration testing, implementation, and production support.
# - Solid development skills in Oracle tools and technologies including Oracle Forms and Oracle Reports.
# - Designed and developed various Oracle Forms and Reports for both Oracle Applications and Custom Development.
# - Experience in Scripting using SQL, PL/SQL, UNIX Shell programs and providing production Support.
# - Experience in Database design using Normalization and E/R Diagrams .
# - Experience in configuration, development, and testing of AutoSys and other scripts.
# - Experience in data loading from other databases and text files into Oracle database using SQL*Loader .
# - Used Query tuning techniques for better performance and execution through suitable Indexes, primary-foreign key constraints.
# - Experience in working with SQL Server Reporting Tools (SSRS) and SQL Server Integration (SSIS).
# - Hands on experience in ETL process using different ETL tools and using PLSQL to populate the tables in OLTP and OLAP Data warehousing environment.
# - Experience with XML packages, XML parsing and loading into Oracle.
# - Experience in COBOL to analyze and modify Open Cobol modules.
# - Expertise in using tools such as TOAD, Oracle SQL Developer , SQL*Plus .
# - Experience in writing Technical design documents and developing Unit Test documents.
# - Very good knowledge in C/C++ , Java Script , Core Java .
#
# TECHNICAL SKILLS:
# - Operating System: Windows 7/10, Linux, UNIX (Sun Solaris, HP-UX).
# - Oracle 12c/11g/10g/9i, MS: SQL Server.
# - Web Technologies: HTML, DHTML, Java Script, XML.
# - Languages: C, C++, SQL, PL/ SQL.
# - Scripting Languages: UNIX Shell Scripting
# - Database Tools: SQL*PLUS, TOAD, SQL*Tool, PL/SQL Developer
# - MS: Office (Access, Word, Excel, PowerPoint)
# - Version Control: CVS, SVN, GITHUB
# - Agile Tools/Methodologies: Jira, RTC, SCRUM
#
# EXPERIENCES:
#
# --- Experience 1 ---
# Job Role: Oracle PL/SQL Developer
# Environment: Oracle 11g/10g, SQL, PLSQL, Shell Scripting, Putty, JavaScript, Oracle SQL Developer, Toad, AutoSys, UNIX, Notepad++.
# Responsibilities:
# - Developed various PL/SQL objects like procedures, functions, packages, and triggers in accordance with the business needs.
# - Involved in interacting with the end-user (client) to gather business requirements and modeling the business requirements.
# - Participated in analyzing the requirements for the logical and physical design of the database.
# - Involved in tuning and query optimizing SQL queries by using quest control tools and manual by EXPLAIN PLAN .
# - PL/SQL Collections were extensively used for high performance of stored procedures.
# - Collaborate with the DBA and Development Team in successful implementation of data warehouse release.
# - Populating the data warehouse tables using SQL*Loader .
# - Implemented complex views, procedures, functions, packages, and triggers in PL/SQL.
# - Performed exception handling for data that did not conform to the required format.
# - Responsible for making the merged data in turn available to other clients.
# - Implemented PL/SQL scripts in accordance with the necessary Business rules and procedures.
# - Applications database pool monitoring and thread monitoring in the JVM .
# - Developed PL/SQL packages and procedures for the back-end processing of the proposed data base design.
# - Created JavaScript to create end-user application, conduct testing and training, design user interface.
# - Coded PL/SQL Procedures, Functions, and Packages for batch processing of the applications.
# - Conducted PL/SQL training session for co-workers to educate about the latest PL/SQL features, PL/SQL performance tuning.
#
# --- Experience 2 ---
# Job Role: Oracle PL/SQL Developer.
# Environment: Oracle 12c/11g, TOAD, Oracle SQL Developer, Shell Scripts, Microsoft Visual Source Safe, Core FTP LE, PUTTY, Open Cobol, Forms Builder, Forms API Master, Oracle Forms 11g/12c, Oracle Reports 11g/12c.
# Responsibilities:
# - Worked to Analyze, Design, Development, and testing of the application.
# - Participate in development of the application by writing procedures, Functions, Triggers, Cursors, Complex SQL queries etc.
# - Developed, Analyzing, and writing PL/SQL scripts. Ability to use advanced features such as ref cursors and built in package/complex SQL statements using multi table joins, exist clauses and ability to tune SQL.
# - Worked on the scripts for Open COBOL modules according to the business requirement.
# - Developed Test plans and Unit Testing , System Integration Testing through Production implementation
# - Developed Oracle Forms and Reports as per client requirements and making them web enabled using Oracle Reports builder 11g/12c and Oracle Forms builder 11g/12c respectively in Web logic environment.
# - Developed reports using complex queries as per business user request as a part of production support.
# - Created and modified several UNIX Shell Scripts according to the changing needs of the project and client requirements.
# - Developed Unix Shell Scripts to process the files on daily basis like renaming the file, extracting date from the file, unzipping the file and remove the junk characters from the file before loading them into the base tables.
# - Interacted with requirements team for new business requirements or enhancements or change requests to implement in the application.
# - Created high quality and well documented code according to standards.
# - Involved in daily status calls and meetings through Agile.
#
# --- Experience 3 ---
# Job Role: Oracle PL/SQL Developer.
# Environment: Oracle 12c/11g, UNIX, Sybase 9.0, TOAD, JavaScript, Oracle SQL Developer, Oracle Forms 11g, Oracle Reports 11g, Putty, Shell Scripts, AutoSys
# Responsibilities:
# - Developed PL/SQL Packages , Procedures, and Functions in accordance with the business requirements for extracting legacy data and loading data into database tables as part of data migration.
# - Involved as a key team member for Requirement Analysis during the design phase and developed various Design documents according to the user requirements.
# - Involved in Code Reviews and preparing Unit test cases.
# - Used Quest code tester for Oracle, a component of Toad used to identify and eliminate the costly bugs and functional errors and used right data model for the data mart based on the requirements.
# - Created technical mapping documents as part of data modeling and design.
# - Created data stores, interfaces, procedures, packages, and scenarios in ODI repositories.
# - Designed and generated Oracle Forms and Oracle Reports .
# - Developed UNIX Shell scripts to automate repetitive database processes.
# - Generated dynamic web-reports using HTML, JavaScript.
# - Efficiently designed the Database schema suitable for the client requirements. Implemented the Client-side HTML/ java script based Pages for User Interaction with the system.
# - Coded several Unix Scripts to interface with several external databases, Sybase ASE and SQL Server and packaged applications. customers in troubleshooting issues with their applications in AutoSys .
# - Physical Data Warehouse design, table partitioning, indexing strategy , materialized views, hands on with PL/ SQL, SQL development using packages and program units.
# - Developed PL/SQL functions to facilitate business functions and calculations and did required modifications to the existing once.
# - Created complex stored procedures, views, SQL joins and scripts .
# - Create and edit SSIS packages including error management and logging.
#
# --- Experience 4 ---
# Job Role: Oracle PL/SQL Developer.
# Environment: Oracle 11g/10g, SQL*Loader, SQL, PLSQL, Putty, Shell Scripting, Informatica 9.0, Oracle SQL Developer, TOAD.
# Responsibilities:
# - Developed PL/SQL Procedures and Functions accordance with the business requirements for loading data into database tables.
# - Created PL/SQL packages for calculation of metrics statistics across 13 states by including state and domain wise parameters which resulted in reducing the report generation time by almost 90%.
# - Developed the SQL code for performance and penalty statistics calculation.
# - Analyzed and framed the business logic for the ETL process as per the requirements.
# - Created ETL Processes using Informatica Version 9.0 .
# - Executing Daily and Monthly reports in UNIX and automated the scripts using shell script.
# - Created SQL Loader scripts to load data into temporary staging tables.
# - Created scripts for Views, Materialized Views and Partitioned tables.
# - Responsible for Analyzing and Implementing the Change Requests
# - Monitoring day-to-day Process for different Data Loads and resolving Issues.
# - Created complex stored procedures, views, SQL joins and scripts.
# - Writing high quality and well documented code according to standards.
# - Involved in fine tuning stored procedures by making use of PL/SQL Collections and its BULK FETCH and BULK INSERT features.
# - Involved in daily status calls with clients.
#
# --- Experience 5 ---
# Job Role: Oracle Developer
# Environment: Oracle 10g, SQL, PL/SQL, Oracle Forms, Oracle Reports, Java, Putty, TOAD, XML, HTML, UNIX, SQL*Loader.
# Responsibilities:
# - Created various SQL and PL/SQL scripts for verification of the required functionalities.
# - Created Custom Triggers, Stored Procedures, Packages, and SQL Scripts .
# - Created numerous web based Forms and Reports.
# - Loaded traffic data logs into staging tables using SQL loader and shell scripts.
# - Developed Forms, Packages, Triggers , and Shell Scripts to load the staging table data into Traffic Mart System .
# - Writing scripts to create partitions, exchange partitions, analyze for performance tuning.
# - Developed packages, functions, procedures, database triggers as part of the ETL process.
# - Used UTL FILE (file handler), DBMS JOB, DBMS ALERT and other utility built-in Packages in PL/SQL.
# - Worked on complete SDLC (System Development Life Cycle) including system analysis, high level design, detailed design, developing, coding, and testing.
# - Creation of database objects like tables, views, procedures, packages using SQL* Plus and PL/SQL .
# - Performed Data validations and mappings at staging table level.
# - Created Complex Dynamic / Static / Parameterized Reports and Charts using Report 6i.
